# %% [markdown]
# #               Jigsaw Unintended Bias in Toxicity Classification

# %% [markdown]
# <h1> 1. Business Problem
#
# <h3> 1.1 Description:</h3>
#     The Conversation AI team, a research initiative founded by Jigsaw and Google (both part of Alphabet), builds technology to protect voices in conversation.
#     A main area of focus is machine learning models that can identify toxicity in online conversations, where toxicity is defined as anything rude, disrespectful or otherwise likely to make someone leave a discussion.
#     They use data by human raters to improve civility in online conversations for various toxic conversational attributes.
#
#    <h3>1.2 Context:</h3>
#     This is a Kaggle competetion: https://www.kaggle.com/c/jigsaw-unintended-bias-in-toxicity-classification/overview
#
#    <h3>1.3 Data:</h3>
#     train.csv, test.csv (Download from Kaggle)
#
#    <h3>1.4 Output to be submitted:</h3>
#     It is in format submission.csv (Download from Kaggle)

# %% [markdown]
# <h1> 2. Machine Learning Problem Foundation
#
# <h2>2.1 Data overview</h2>
#
# Attribute information:
# * comment_text: text of individual comments
#
# * target: toxicity label( to be predicted to for test data. target>=0.5 will be consider to be postive class(toxic))
#
#
# Identity Attributes:
# * male
# * female
# * transgender
# * other_gender
# * heterosexual
# * homosexual_gay_or_lesbian
# * bisexual
# * other_sexual_orientation
# * christian
# * jewish
# * muslim
# * hindu
# * buddhist
# * atheist
# * other_religion
# * black
# * white
# * asian
# * latino
# * other_race_or_ethnicity
# * physical_disability
# * intellectual_or_learning_disability
# * psychiatric_or_mental_illness
# * other_disability

# %% [markdown]
# # 3. Load Libraries

# %%
#Loading Libraries

# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
import string
import nltk

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from bs4 import BeautifulSoup

import contractions

from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.feature_extraction.text import CountVectorizer
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, auc,roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

from gensim.models import Word2Vec
from gensim.models import KeyedVectors
import pickle
import gc

import os
import re
from tqdm import tqdm

from keras.layers import Embedding
from keras.layers import Input
from keras.layers import Conv1D
from keras.layers import MaxPooling1D
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers import Dense
from keras.optimizers import RMSprop
from keras.models import Model
from keras.models import load_model
from keras.callbacks import LearningRateScheduler

from keras_bert import load_trained_model_from_checkpoint, load_vocabulary
from keras_bert import Tokenizer
from keras_bert import AdamWarmup, calc_train_steps
from keras.losses import binary_crossentropy
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # 4. Exploratory Data Analysis

# %% [markdown]
# <h2> 4.1 Load Data

# %%
tr_data=pd.read_csv("../Data/train.csv")
test_data=pd.read_csv("../Data/test.csv")
#submission = pd.read_csv('../Data/sample_submission.csv', index_col='id')

#tr_data=pd.read_csv("../input/jigsaw-unintended-bias-in-toxicity-classification/train.csv")
#test_data=pd.read_csv("../input/jigsaw-unintended-bias-in-toxicity-classification/test.csv")
#submission = pd.read_csv('../input/jigsaw-unintended-bias-in-toxicity-classification/sample_submission.csv', index_col='id')

# %%
print("Shape of tr_data",tr_data.shape)
print("Shape of test_data",test_data.shape)

tr_data.head()
# Out:
# Shape of tr_data (1804874, 45)
# Shape of test_data (97320, 2)
#       id    target                                       comment_text  \
# 0  59848  0.000000  This is so cool. It's like, 'would you want yo...
# 1  59849  0.000000  Thank you!! This would make my life a lot less...
# 2  59852  0.000000  This is such an urgent design problem; kudos t...
# 3  59855  0.000000  Is this something I'll be able to install on m...
# 4  59856  0.893617               haha you guys are a bunch of losers.
#
#    severe_toxicity  obscene  identity_attack   insult  threat  asian  atheist  \
# 0         0.000000      0.0         0.000000  0.00000     0.0    NaN      NaN
# 1         0.000000      0.0         0.000000  0.00000     0.0    NaN      NaN
# 2         0.000000      0.0         0.000000  0.00000     0.0    NaN      NaN
# 3         0.000000      0.0         0.000000  0.00000     0.0    NaN      NaN
# 4         0.021277      0.0         0.021277  0.87234     0.0    0.0      0.0
#
#    ...  article_id    rating  funny  wow  sad  likes  disagree  \
# 0  ...        2006  rejected      0    0    0      0         0
# 1  ...        2006  rejected      0    0    0      0         0
# 2  ...        2006  rejected      0    0    0      0         0
# 3  ...        2006  rejected      0    0    0      0         0
# 4  ...        2006  rejected      0    0    0      1         0
#
#    sexual_explicit  identity_annotator_count  toxicity_annotator_count
# 0              0.0                         0                         4
# 1              0.0                         0                         4
# 2              0.0                         0                         4
# 3              0.0                         0                         4
# 4              0.0                         4                        47
#
# [5 rows x 45 columns]

# %% [markdown]
# Data overview
# Attribute information:
# * comment_text: text of individual comments
# * target: toxicity label( to be predicted to for test data. target>=0.5 will be consider to be positive class(toxic))
#
#
# When the Conversation AI team first built toxicity models, they found that the models incorrectly learned to associate the names of frequently attacked identities with toxicity. Models predicted a high likelihood of toxicity for comments containing those identities (e.g. "gay"), even when those comments were not actually toxic (such as "I am a gay woman"). This happens because training data was pulled from available sources where unfortunately, certain identities are overwhelmingly referred to in offensive ways.
# There are some identity attributes which are taken care:
# asian, atheist, bisexual, black, buddhist, christian, female, heterosexual, hindu, homosexual_gay_or_lesbian, intellectual_or_learning_disability, jewish, latino, male, muslim, other_disability, other_gender, other_race_or_ethnicity, other_religion, other_sexual_orientation, physical_disability, psychiatric_or_mental_illness, transgender, white.

# %%
# Create dataset with comment text, target and identity_attributes and drop other columns from train_data
identity_attribute=['male', 'female','homosexual_gay_or_lesbian', 'muslim', 'christian', 'jewish','white', 'black', 'psychiatric_or_mental_illness']


aux_columns = ['target', 'severe_toxicity','obscene','identity_attack','insult','threat','sexual_explicit']
data=tr_data[['comment_text']]
data1=tr_data[identity_attribute]
data2=tr_data[aux_columns]
data=pd.concat([data,data1,data2],axis=1)
data[29:34]
# Out:
#                                          comment_text  male  female  \
# 29  I applaud Civil's efforts to create some new t...   NaN     NaN
# 30  Why bother writing a review if it's going to b...   NaN     NaN
# 31  Yet call out all Muslims for the acts of a few...   0.0     0.0
# 32  I love the idea of upvoting entire articles, t...   NaN     NaN
# 33                             Troll free since 2016.   NaN     NaN
#
#     homosexual_gay_or_lesbian  muslim  christian  jewish  white  black  \
# 29                        NaN     NaN        NaN     NaN    NaN    NaN
# 30                        NaN     NaN        NaN     NaN    NaN    NaN
# 31                        0.0     1.0        1.0     0.0    0.0    0.0
# 32                        NaN     NaN        NaN     NaN    NaN    NaN
# 33                        NaN     NaN        NaN     NaN    NaN    NaN
#
#     psychiatric_or_mental_illness  target  severe_toxicity  obscene  \
# 29                            NaN  0.0000             0.00   0.0000
# 30                            NaN  0.0000             0.00   0.0000
# 31                            0.0  0.9125             0.05   0.2375
# 32                            NaN  0.0000             0.00   0.0000
# 33                            NaN  0.0000             0.00   0.0000
#
#     identity_attack  insult  threat  sexual_explicit
# 29           0.0000  0.0000  0.0000              0.0
# 30           0.0000  0.0000  0.0000              0.0
# 31           0.6125  0.8875  0.1125              0.0
# 32           0.0000  0.0000  0.0000              0.0
# 33           0.0000  0.0000  0.0000              0.0

# %%
x_data = data['comment_text']
y_aux_data = data[aux_columns].fillna(0).values

# Initialize weights

# Overall
weights = np.ones((len(data),)) / 4
# Subgroup
weights += (data[identity_attribute].fillna(0).values >= 0.5).sum(axis=1).astype(bool).astype(np.int) / 4
# Background Positive, Subgroup Negative
weights += (((data['target'].values >= 0.5).astype(bool).astype(np.int) +
            (data[identity_attribute].fillna(0).values < 0.5).sum(axis=1).astype(bool).astype(np.int)) > 1).astype(bool).astype(np.int) / 4
# Background Negative, Subgroup Positive
weights += (((data['target'].values < 0.5).astype(bool).astype(np.int) +
             (data[identity_attribute].fillna(0).values >= 0.5).sum(axis=1).astype(bool).astype(np.int)) > 1).astype(bool).astype(np.int) / 4
#Normalize them
#weights/= weights.mean()
loss_weight = 1.0 / weights.mean()
y_data=data['target'].values

#y = np.vstack([(data['target'].values >= 0.5).astype(np.int), weights]).T

#y_aux = np.hstack([y, y_aux_data])
for column in identity_attribute +  ['target'] : 
    data[column] = np.where(data[column] >=0.5, True, False)

# %%
data.head()
# Out:
#                                         comment_text   male  female  \
# 0  This is so cool. It's like, 'would you want yo...  False   False
# 1  Thank you!! This would make my life a lot less...  False   False
# 2  This is such an urgent design problem; kudos t...  False   False
# 3  Is this something I'll be able to install on m...  False   False
# 4               haha you guys are a bunch of losers.  False   False
#
#    homosexual_gay_or_lesbian  muslim  christian  jewish  white  black  \
# 0                      False   False      False   False  False  False
# 1                      False   False      False   False  False  False
# 2                      False   False      False   False  False  False
# 3                      False   False      False   False  False  False
# 4                      False   False      False   False  False  False
#
#    psychiatric_or_mental_illness  target  severe_toxicity  obscene  \
# 0                          False   False         0.000000      0.0
# 1                          False   False         0.000000      0.0
# 2                          False   False         0.000000      0.0
# 3                          False   False         0.000000      0.0
# 4                          False    True         0.021277      0.0
#
#    identity_attack   insult  threat  sexual_explicit
# 0         0.000000  0.00000     0.0              0.0
# 1         0.000000  0.00000     0.0              0.0
# 2         0.000000  0.00000     0.0              0.0
# 3         0.000000  0.00000     0.0              0.0
# 4         0.021277  0.87234     0.0              0.0

# %%
#y_data=np.where(data['target']>= 0.5, 1, 0)
y_data= np.vstack([(data['target'].values>=0.5).astype(np.int),weights]).T
y_data
# Out:
# array([[0.  , 0.25],
#        [0.  , 0.25],
#        [0.  , 0.25],
#        ...,
#        [0.  , 0.25],
#        [1.  , 0.5 ],
#        [0.  , 0.25]])

# %% [markdown]
# <h2>4.2 Data Preprocessing

# %% [markdown]
# Text Preprocessing
#
# In the Preprocessing phase we do the following in the order below:-
#
# 1. Begin by removing the html tags
# 2. Remove any punctuations or limited set of special characters like , or . or # etc.
# 3. Check if the word is made up of english letters and is not alpha-numeric
# 4. Check to see if the length of the word is greater than 2 (as it was researched that there is no adjective in 2-letters)
# 5. Convert the word to lowercase
# 6. Remove Stopwords
# 7. Expand contractions
# 8. Finally Snowball Stemming the word (it was obsereved to be better than Porter Stemming)<br>

# %%
#Preprocessing steps to delete and isolate unwanted symbols
symbols_to_delete = '→★©®●ː☆¶）иʿ。ﬂﬁ₁♭年▪←ʒ、（月■⇌ɹˤ³の¤‿عدويهصقناخلىبمغرʀɴשלוםביエンᴵאעכח‐ικξتحكسةفزط‑地谷улкноה歌мυтэпрдˢᵒʳʸᴺʷᵗʰᵉᵘοςתמדףנרךצט成都ех小土》करमा英文レクサス外国人бьыгя不つзц会下有的加大子ツشءʲшчюж戦щ明קљћ我出生天一家新ʁսհןجі‒公美阿ספ白マルハニチロ社ζ和中法本士相信政治堂版っфچیリ事「」シχψմեայինրւդک《ლさようならعدويهصقناخلىبمغرʀɴשלוםביエンᴵאעכח‐ικξتحكسةفزط‑地谷улкноה歌мυтэпрдˢᵒʳʸᴺʷᵗʰᵉᵘοςתמדףנרךצט成都ех小土》करमा英文レクサス外国人бьыгя不つзц会下有的加大子ツشءʲшчюж戦щ明קљћ我出生天一家新ʁսհןجі‒公美阿ספ白マルハニチロ社ζ和中法本士相信政治堂版っфچیリ事「」シχψմեայինրւդک《ლさようなら\n＼🍕\r🐵😑\xa0\ue014≠\t\uf818\uf04a\xad😢🐶❤️☺\uf0e0😜😎👊\u200b\u200e😁أ😍💖̶💵❥━┣┫Е┗Ｏ►👎😀😂\u202a\u202c🔥😄🏻💥ᴍʏᴇᴅᴏᴀᴋʜᴜʟᴛᴄᴘʙғᴊᴡɢ✔\x96\x92😋👏😱‼\x81ジ故障➤\u2009🚌͞🌟😊😳😧🙀😐😕\u200f👍😮😃😘☕♡◐║▬💩💯⛽🚄🏼ஜ۩۞😖ᴠ🚲✒➥😟😈═ˌ💪🙏🎯◄🌹😇💔😡\x7f👌ἐὶήὲἀίῃἴ🙄✬ＳＵＰＥＲＨＩＴ😠\ufeff☻\u2028😉😤⛺♍🙂\u3000👮💙😏🍾🎉😞\u2008🏾😅😭👻😥😔😓🏽🎆✓◾🍻🍽🎶🌺🤔😪\x08؟🐰🐇🐱🙆😨⬅🙃💕𝘊𝘦𝘳𝘢𝘵𝘰𝘤𝘺𝘴𝘪𝘧𝘮𝘣💗💚獄℅ВПАН🐾🐕❣😆🔗🚽舞伎🙈😴🏿🤗🇺🇸♫ѕＣＭ⤵🏆🎃😩█▓▒░\u200a🌠🐟💫💰💎\x95🖐🙅⛲🍰⭐🤐👆🙌\u2002💛🙁👀🙊🙉\u2004❧▰▔ᴼᴷ◞▀\x13🚬▂▃▄▅▆▇↙🤓\ue602😵άόέὸ̄😒͝☹➡🆕👅👥👄🔄🔤👉👤👶👲🔛🎓\uf0b7✋\uf04c\x9f\x10😣⏺̲̅😌🤑́🌏😯😲∙‛Ἰᾶὁ💞🚓◇🔔📚✏🏀👐\u202d💤🍇\ue613豆🏡▷❔❓⁉❗\u202f👠्🇹🇼🌸蔡🌞˚🎲😛˙关系С💋💀🎄💜🤢َِ✨是\x80\x9c\x9d🗑\u2005💃📣👿༼◕༽😰ḷЗ▱￼🤣卖温哥华议降％你失去所钱拿坏税骗🐝¯🎅\x85🍺آإ🎵🌎͟ἔ油别克🤡🤥😬🤧й\u2003🚀🤴⌠ИОРФДЯМ✘😝🖑ὐύύ特殊作群╪💨圆园▶ℐ☭✭🏈😺♪🌍⏏ệ🍔🐮🍁☔🍆🍑🌮🌯☠🤦\u200d♂𝓒𝓲𝓿𝓵안영하세요ЖК🍀😫🤤ῦ在了可以说普通话汉语好极🎼🕺☃🍸🥂🗽🎇🎊🆘☎🤠👩✈🖒✌✰❆☙🚪⚲\u2006⚭⚆⬭⬯⏖○‣⚓∎ℒ▙☏⅛✀╌🇫🇷🇩🇪🇮🇬🇧😷🇨🇦ХШ🌐\x1f杀鸡给猴看𝗪𝗵𝗲𝗻𝘆𝗼𝘂𝗿𝗮𝗹𝗶𝘇𝗯𝘁𝗰𝘀𝘅𝗽𝘄𝗱📺ｃϖ\u2000үａᴦᎥһͺ\u2007ｓǀ\u2001ɩ℮ｙｅ൦ｌƽ¸ｗｈ𝐓𝐡𝐞𝐫𝐮𝐝𝐚𝐃𝐜𝐩𝐭𝐢𝐨𝐧Ƅᴨᑯ໐ΤᏧ௦Іᴑ܁𝐬𝐰𝐲𝐛𝐦𝐯𝐑𝐙𝐣𝐇𝐂𝐘𝟎ԜТᗞ౦〔Ꭻ𝐳𝐔𝐱𝟔𝟓𝐅🐋∼ﬃ💘💓ё𝘥𝘯𝘶💐🌋🌄🌅𝙬𝙖𝙨𝙤𝙣𝙡𝙮𝙘𝙠𝙚𝙙𝙜𝙧𝙥𝙩𝙪𝙗𝙞𝙝𝙛👺🐷ℋℳ𝐀𝐥𝐪❄🚶𝙢Ἱ🤘ͦ💸☼패티Ｗ⋆𝙇ᵻ👂👃ɜ🎫\uf0a7БУ🚢🚂ગુજરાતીῆ🏃𝓬𝓻𝓴𝓮𝓽𝓼☘﴾͡๏̯﴿⚾⚽Φ₽\ue807𝑻𝒆𝒍𝒕𝒉𝒓𝒖𝒂𝒏𝒅𝒔𝒎𝒗𝒊👽😙\u200cЛ🎾👹￦⎌🏒⛸寓养宠物吗🏄🐀🚑🤷操𝒑𝒚𝒐𝑴🤙🐒℃欢迎来到拉斯𝙫⏩☮🐈𝒌𝙊𝙭𝙆𝙋𝙍𝘼𝙅ﷻ⚠🦄巨收赢得鬼愤怒要买额ẽ🚗✊🐳𝟏𝐟𝟖𝟑𝟕𝒄𝟗𝐠𝙄𝙃👇锟斤拷❌⭕▸𝗢𝟳𝟱𝟬⦁株式⛷한국어ㄸㅓ니͜ʖ𝘿𝙔₵𝒩ℯ𝒾𝓁𝒶𝓉𝓇𝓊𝓃𝓈𝓅ℴ𝒻𝒽𝓀𝓌𝒸𝓎𝙏𝙟𝘃𝗺𝟮𝟭𝟯𝟲👋🦊☐☑多伦⚡☄ǫ🐽🎻🎹⛓🏹╭╮🍷🦆为友谊祝贺与其想象对如直接问用自己猜传教没积唯认识基督徒曾经让耶稣复活死怪他但当们聊些题时候例战胜因圣把全结婚孩恐惧且栗谓这样还♾🎸🤕🤒⛑🎁批判检讨🏝🦁＞ʕ̣Δ🙋😶쥐스탱트뤼도석유가격인상이경제황을렵게만들지않록잘관리해야합다캐나에서대마초와화약금의품런성분갈때는반드시허된사용✞🔫👁┈╱╲▏▕┃╰▊▋╯┳┊☒凸ὰ💲🗯𝙈Ἄ𝒇𝒈𝒘𝒃𝑬𝑶𝕾𝖙𝖗𝖆𝖎𝖌𝖍𝖕𝖊𝖔𝖑𝖉𝖓𝖐𝖜𝖞𝖚𝖇𝕿𝖘𝖄𝖛𝖒𝖋𝖂𝕴𝖟𝖈𝕸👑🚿☝💡知彼百\uf005𝙀𝒛𝑲𝑳𝑾𝒋𝟒😦𝙒𝘾𝘽🏐𝘩𝘨ὼṑ✅☛𝑱𝑹𝑫𝑵𝑪🇰🇵👾ᓇᒧᔭᐃᐧᐦᑳᐨᓃᓂᑲᐸᑭᑎᓀᐣ🐄🎈🔨♩🐎🤞☞🐸💟🎰🌝🛳点击查🍭𝑥𝑦𝑧ＡＮＧＪＢ👣\uf020◔◡🏉💭🎥♀Ξ🐴👨🤳⬆🦍\x0b🍩𝑯𝒒😗𝟐🏂👳🍗🕉🐲̱ℏ𝑮𝗕𝗴\x91🍒⠀ꜥⲣⲏ╚🐑⏰↺⇤∏鉄件✾◦♬ї💊\uf203\uf09a\uf222\ue608\uf202\uf099\uf469\ue607\uf410\ue600燻製虚偽屁理屈｜Г𝑩𝑰𝒀𝑺🌤∵∴𝗳𝗜𝗙𝗦𝗧🍊ὺἈἡῖΛΩ⤏🇳𝒙Ձռձ冬至ὀ𝒁🔹🤚🍎𝑷🐂💅𝘬𝘱𝘸𝘷𝘐𝘭𝘓𝘖𝘹𝘲𝘫☜Βώ💢▲ΜΟΝΑΕ🇱♲𝝈↴↳💒⊘▫Ȼ⬇🚴🖕🖤🥘📍👈➕🚫🎨🌑🐻𝐎𝐍𝐊𝑭🤖🎎✧😼🕷ｇｏｖｒｎｍｔｉｄｕ２０８ｆｂ＇ｋ𝟰🇴🇭🇻🇲𝗞𝗭𝗘𝗤👼📉🍟🍦∕🌈🔭🐊🐍\uf10aˆ⚜☁ڡ🐦\U0001f92f\U0001f92a🐡💳ἱ🙇𝗸𝗟𝗠𝗷🥜🔼'
symbols_to_isolate = '.,?!-;*"…:—()%#$&_/@・ω+=”“[]^–>\\°<~•™ˈʊɒ∞§{}·ταɡ|¢`―ɪ£♥´¹≈÷′ɔ€†μ½ʻπδηλσερνʃ±µº¾．»ав⋅¿¬β⇒›¡₂₃γ″«φ⅓„：¥сɑ！−²ʌ¼⁴⁄₄‚‖⊂⅔¨×θ？∩，ɐ₀≥↑↓／√－‰≤'
isolate_dict = {ord(c):f' {c} ' for c in symbols_to_isolate}
remove_dict = {ord(c):f'' for c in symbols_to_delete}

# %%
#Contraction map to decontract the phrases
CONTRACTION_MAP = {
"ain't": "is not",
"aren't": "are not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he would",
"he'd've": "he would have",
"he'll": "he will",
"he'll've": "he he will have",
"he's": "he is",
"how'd": "how did",
"how'd'y": "how do you",
"how'll": "how will",
"how's": "how is",
"I'd": "I would",
"I'd've": "I would have",
"I'll": "I will",
"I'll've": "I will have",
"I'm": "I am",
"I've": "I have",
"i'd": "i would",
"i'd've": "i would have",
"i'll": "i will",
"i'll've": "i will have",
"i'm": "i am",
"i've": "i have",
"isn't": "is not",
"it'd": "it would",
"it'd've": "it would have",
"it'll": "it will",
"it'll've": "it will have",
"it's": "it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"mightn't've": "might not have",
"must've": "must have",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"needn't've": "need not have",
"o'clock": "of the clock",
"oughtn't": "ought not",
"oughtn't've": "ought not have",
"shan't": "shall not",
"sha'n't": "shall not",
"shan't've": "shall not have",
"she'd": "she would",
"she'd've": "she would have",
"she'll": "she will",
"she'll've": "she will have",
"she's": "she is",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"so've": "so have",
"so's": "so as",
"that'd": "that would",
"that'd've": "that would have",
"that's": "that is",
"there'd": "there would",
"there'd've": "there would have",
"there's": "there is",
"they'd": "they would",
"they'd've": "they would have",
"they'll": "they will",
"they'll've": "they will have",
"they're": "they are",
"they've": "they have",
"to've": "to have",
"wasn't": "was not",
"we'd": "we would",
"we'd've": "we would have",
"we'll": "we will",
"we'll've": "we will have",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what will",
"what'll've": "what will have",
"what're": "what are",
"what's": "what is",
"what've": "what have",
"when's": "when is",
"when've": "when have",
"where'd": "where did",
"where's": "where is",
"where've": "where have",
"who'll": "who will",
"who'll've": "who will have",
"who's": "who is",
"who've": "who have",
"why's": "why is",
"why've": "why have",
"will've": "will have",
"won't": "will not",
"won't've": "will not have",
"would've": "would have",
"wouldn't": "would not",
"wouldn't've": "would not have",
"y'all": "you all",
"y'all'd": "you all would",
"y'all'd've": "you all would have",
"y'all're": "you all are",
"y'all've": "you all have",
"you'd": "you would",
"you'd've": "you would have",
"you'll": "you will",
"you'll've": "you will have",
"you're": "you are",
"you've": "you have"
}

# %%
#Code ref: https://www.kdnuggets.com/2018/08/practitioners-guide-processing-understanding-text-2.html
def expand_contractions(text, contraction_mapping=CONTRACTION_MAP):
    """decontract the phrases"""
    
    contractions_pattern = re.compile('({})'.format('|'.join(contraction_mapping.keys())), 
                                      flags=re.IGNORECASE|re.DOTALL)
    def expand_match(contraction):
        match = contraction.group(0)
        first_char = match[0]
        expanded_contraction = contraction_mapping.get(match)\
                                if contraction_mapping.get(match)\
                                else contraction_mapping.get(match.lower())                       
        expanded_contraction = first_char+expanded_contraction[1:]
        return expanded_contraction
        
    expanded_text = contractions_pattern.sub(expand_match, text)
    expanded_text = re.sub("'", "", expanded_text)
    return expanded_text

# %%
#English stopwards to be removed
stopwords= set(['br', 'the', 'i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've",\
            "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', \
            'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their',\
            'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', \
            'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', \
            'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', \
            'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after',\
            'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further',\
            'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more',\
            'most', 'other', 'some', 'such', 'only', 'own', 'same', 'so', 'than', 'too', 'very', \
            's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', \
            've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn',\
            "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn',\
            "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", \
            'won', "won't", 'wouldn', "wouldn't"])

# %%
# Implementing all pre-processing steps
from tqdm import tqdm
preprocessed_data = []
stemmer = SnowballStemmer("english")
#nltk.download('wordnet')
lemmatizer = WordNetLemmatizer() 

if os.path.exists('preprocessed_data.npy'):
    print("Loading preprocessed data")
    preprocessed_data = np.load('preprocessed_data.npy')
else:
    for sentance in (data['comment_text'].values):
        sentance = re.sub(r"http\S+", "", sentance)  #Removing http/https tag
        #sentance = expand_contractions(sentance) # expanded short words like n't to not
        sentance = BeautifulSoup(sentance, 'lxml').get_text() # Removing xml tags
        #sentance = contractions.fix(sentance)
        sentance = sentance.translate(remove_dict)
        sentance = sentance.translate(isolate_dict)


        sentance = re.sub("\S*\d\S*", "", sentance).strip() # Remove words with numbers
        sentance = re.sub('[^A-Za-z]+', ' ', sentance) # remove special characters
        sentance = stemmer.stem(sentance)
        sentance = lemmatizer.lemmatize(sentance)
        preprocessed_data.append(' '.join(token.lower() for token in nltk.word_tokenize(sentance) ))
    #np.save('preprocessed_data', preprocessed_data)
# Out:
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'...'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.....'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'You are absolutely right...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'...'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'. . . No Kidding.\nGee, what the heck happened? Reality kick-in -- finally.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b"Oh come on . . . how about drinking up the 'half-full' instead of staring at the 'half-empty'...\n\n/.."" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'. . . Nope, just a pi$$ed off customer who got the boots put to their head.\n\nThe events are real, friend...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Looks like it time to go back for the rest of the education . . .  to earn a decent living.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'...'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'. . . Exactly.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Well Said...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Well Said...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Well Said..\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b". . . and then there are those whose wish list includes the election of Marine Le Pen to France's presidency..\n\n/.."" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Exactly...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Thank you... Precisely!\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Excellent Logic... Well Said.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'That is quite right. . . Well Said.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Nicely said...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Seems to be the case...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Yes indeed..\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Well Said...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Exactly. . . \n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'What nonsense. . . Slandering this Doctor is absolutely ridiculous..\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'The Sale of Hydro One is completely disgusting...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Nicely said... \n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'" Seems to me the Star has lost its way."\n\n. . . one singular opinion based on what seems to be \'full-blown prejudice\'..\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b"Ain't it the truth...\n\n/.."" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Oh come-on ... that was absolutely hilarious!\n\nIt just has to be a joke.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Get a therapist, Sara because this obsessive-compulsion with Trump is becoming quite reiterative & boring. . . \n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b"And that, friend, is no reason for the 'life imprisonment'... that is complete bs ...\n\nBut then vicious is as vicious does... eh, pal.\n\n/.."" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'. . . and yet, here you are. . . eh, pal?\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Steve, Well Said..\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Excellent comment...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Good Grief... Seems the Meritocracy Doctor is in.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Hear! Hear! Jack Canuck!\n\nWell Said.. !\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Well Said.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Suppose only the future will tell.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Interesting though..\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Possibly...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'You nailed it, Lamont.. !!\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'How argumentative... and predictable.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Exactly...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Systematic take over of Canada... Priceless!\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'"Why I won\'t leave London, ever..."\n\nInteresting.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b"The level of 'Censorship' with this story is utterly disgusting, Globe and Mail.\n\n/.."" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b". . . as stated -- 'Let cool heads prevail'..\n\n/.."" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b". . . your comment is just fine.. looks like the 'Comment Police' have shown up and are just getting warmed up with the 'Neggies'..\n\n/.."" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'...'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'You are absolutely right...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'"Ooooh, someone sounds jealous!"\n~ ~ ~ ~\nYou bet... !!\nHey G & M ... *over here* ... It\'s Me!! --  I really want this job.. !!\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Well Said, Bart...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b". . . given his history, it's somewhat obvious.\n\n/.."" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b". . .  seems that 'atheists' are off the grid in this discussion.\n\n/.."" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Excellent Advice...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'. . . and appear to be good buddies with North Korea, the largest ~ 25 Million strong state-sponsored prison on the Planet.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'So Very Well Said...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b"2 years, 3 months, 24 days... till the next Canadian Federal Election..\n\nNo more Majority Gov't Stupidity..\n\n/.."" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b"erratum...\n\nDoesn't seem so...\n\n/.."" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'. . . and China can go to hell.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Nicely Said... and so True.\n\nHappy Canada Day.. !!\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b". . . more 'straw man' tootling..\n\n/.."" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b". . . it's a Liberal thing.\n\n/.."" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Well Said..\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'2003 - 2004 . . . Liberals under Prime Minister Paul Martin.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Excellent synopsis... Well Said.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b". . . spoilt mommy's boy politics.\n\n/.."" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Exactly...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'. . . Liberal Prime Minister Paul Martin.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Well Said...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Nicely said...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Excellent Point...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Ditto...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Sounds good... and then there is reality... one man dead; one man blind; the perpetrator receives an apology & $10 Million Dollars. \n\nYeah...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'. . . he then owes the rest of us $4 Mil. Cdn..\n\nThe apology was enough.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Excellent comment... \n\n. . . which brings this Canadian to the question -- what the heck is going on in Ottawa ???\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b"Apparently, it seems the righteous Mr. E. is not taking calls right now... you know how it is after 'payday'... so much to do.\n\n/.."" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Exactly... Well Said, Canadian.. !!\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Well Said...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b"Elbow to the Mammary Trudeau Canada's Feckless Feminist Prime Minister at Large, that is...\n\n/.."" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Exactly...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Excellent Comment... Well Said.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'You are absolutely right...\n. . plus there are likely a number more to plug into that OC dominated venn..\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'What a wonderful story of Humanitarianism springing into action... repeatedly.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b"Unless greased-up with a slightly torn pocked and rolled up to at the elbows -- they look 'cheesy faux'.\n\n/.."" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Exciting Suff.. !!\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b"I'm with you...\n\n/.."" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'How interesting...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Ditto...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'. . . generalizing statement over a whole population. Tsk Tsk..\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b"No Rust & Well Constructed  -- That's the Ticket.. !!\n\n/.."" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b"That is simply more manipulative propaganda from an experimental gov't which is strong-arming its people.\n\n/.."" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Nicely Said...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b"No kidding... Also looks too face heavy -- needs a design which does not look like its a distended 'box'.. Seems primitive. \n\n/.."" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Good to know...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Well Said.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Teddy Ballgame 9 & MarcDacey: Well Said !\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Deuces Wild - Nicely Said.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'At Last... !! Nicely Said!\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'214Montreal - Well Said.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Excellent Comment... !!\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Alcest: Jews & moderate Muslims are perceived equally in Canada.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Excellent comment.. !!\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'. . . and its time to get rid of it.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Well Said..\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Excellent Article... enjoyed it.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'What a unique concept... looking forward to viewing this film.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'No Kidding..\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'What a megalomaniac...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Okay... That made me smile. Well Said.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Ridiculous trash-talk.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'More trash-talk\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Terrible waste of life...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Excellent Point...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b"Eva, do you have children? It would seem that ridiculing any child is 'low-brow' vitriol ..\n\n/.."" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Well Said...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Well Said..\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Well Said, Canadian...!!\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'You have got to be Kidding ?!?\n\n ... Good Try -- No Cigar. \n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Well Done...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Exactly... Well Said.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Exactly...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Party Hardy Trudeau & Buddy Butts are making this up as they go..\n\nThey intend to take the current Canadian structure apart -- bone by bone.. \n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'The Americans certainly have their problems right now...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Nicely Said...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b". . . likely for having to listen to this woman's bigoted racist trash-talk..\n\n/.."" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Thank you for a poignant post.. Well Said.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'What a strange dumb comment..\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b". . . nothing like falling back on 'unnecessary personal insult' to pejoratively retort to a logical premise...\n\nCheers Canadian.\n\n/.."" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Well Said..\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Man... this Canadian was laughing to tears from your comment... Priceless.. !\n\nYou coined the perfect comparative simile..\n\nCheers! :)\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Well... you never know, Buford.. We here in Canada do hope that is not the case.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Gee, Alceste... Good Try !!.. but Wrong. Just try re-reading the comment.\n\nGood Luck & Cheers, Canadian.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'You are quite right.. Well Said.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'WesternPatriot.. Well Said.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Excellent Insight... Well Said.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Exactly...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b"You nailed it... and now it is time to pay for the 'Majority' we gave them.\n\n. . . and We Canadians will pay dearly.\n\n/.."" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Well Said, OrsonW.. !\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Excellent Comment... Well Said, Teddy.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Exactly.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Well Said.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Well Said.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'CBC got its payoff to the tune of over ~$1.3 Billion..\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Well Said...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Well Said...\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Not at all... welcome Canadian.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Well Said..\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Well Said..\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'...'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'. . . and yet here you are -- mingling.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'. . .  "another" what, Canadian??  Would that be more innocent victims for a pretentious snotty virus??\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'It only takes "courage" if the individual is \'sincere\'. . . otherwise, the "Excuse" is simply manipulation.\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'That fails to make sense..\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\mukesh\Anaconda3\lib\site-packages\bs4\__init__.py:294: UserWarning: "b'Allan, you think.. ?? Gosh, how can you say that??\n\n/..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)

# %%
# Print some sample values of text before and after pre-processing

print(data['comment_text'].values[0])
print('-'*50)
print(preprocessed_data[0])
print('='*50)

print(data['comment_text'].values[100])
print('-'*50)
print(preprocessed_data[100])
print('='*50)

print(data['comment_text'].values[456])
print('-'*50)
print(preprocessed_data[456])
print('='*50)

print(data['comment_text'].values[10000])
print('-'*50)
print(preprocessed_data[10000])
print('='*50)
# Out:
# This is so cool. It's like, 'would you want your mother to read this??' Really great idea, well done!
# --------------------------------------------------
# this is so cool it s like would you want your mother to read this really great idea well done
# ==================================================
# Loving this collection. Cant wait till Season 2 is released. Should be any day now according to http://yeezy-season2.com/
# --------------------------------------------------
# loving this collection cant wait till season is released should be any day now according to
# ==================================================
# The preserve was sold big time to the public, the only version available to the public before the ballot was the version with the preserve. Yes it was deleted from the ballot language, but that is a pull the wool over the eyes trick that gives Metro the excuse to not be accountable. But they and the zoo are accountable for their statements -- which were unequivacally that there would be an offiste preserve for the elephants.  This just proves that we cannot trust our government to tell the truth. But we still need to hold them accountable for their statements to the public.  And since there was so much public outcry about the preserve, Metro did option land, did hold hearings to discuss the plans for the preserve and did target in 2008 $12 million for captital expenses and a feasibility study. So why claim it was never part of the bond? Because all the money was spent on the new exhibit? Or it was a ruse to fool the public about their real intentions to never provide a preserve.
# --------------------------------------------------
# the preserve was sold big time to the public the only version available to the public before the ballot was the version with the preserve yes it was deleted from the ballot language but that is a pull the wool over the eyes trick that gives metro the excuse to not be accountable but they and the zoo are accountable for their statements which were unequivacally that there would be an offiste preserve for the elephants this just proves that we can not trust our government to tell the truth but we still need to hold them accountable for their statements to the public and since there was so much public outcry about the preserve metro did option land did hold hearings to discuss the plans for the preserve and did target in million for captital expenses and a feasibility study so why claim it was never part of the bond because all the money was spent on the new exhibit or it was a ruse to fool the public about their real intentions to never provide a preserve
# ==================================================
# Comfort and your respect for it aside, using epidurals and medications during labor and birth introduces risks also. Setting up any option as one with "absolutely zero risk" is fallacy. This is the excellent thing about choice in our community, we get to evaluate and choose our risks relative to our personal values. (This is where one would ensure "informed choice".)
#
# There are also plenty of mammals who do birth in water, and this article didn't spend much time on people laboring in water and then "hauling out" to actually deliver. That happens quite a bit--I'd be interested in seeing stats but anecdotally, I think it's 50/50 that labor happens with water support but birth happens out of water.
#
# The lead of the article sums it up, factual research about the safety of water birth is drawing praise and worry for the option. With better information comes better training and technology so expecting parents and their care providers can work together toward safer outcomes.
# --------------------------------------------------
# comfort and your respect for it aside using epidurals and medications during labor and birth introduces risks also setting up any option as one with absolutely zero risk is fallacy this is the excellent thing about choice in our community we get to evaluate and choose our risks relative to our personal values this is where one would ensure informed choice there are also plenty of mammals who do birth in water and this article didn t spend much time on people laboring in water and then hauling out to actually deliver that happens quite a bit i d be interested in seeing stats but anecdotally i think it s that labor happens with water support but birth happens out of water the lead of the article sums it up factual research about the safety of water birth is drawing praise and worry for the option with better information comes better training and technology so expecting parents and their care providers can work together toward safer outcomes
# ==================================================

# %% [markdown]
# # 5. Data Splitting

# %%
final=data
final['preprocessed_data']=preprocessed_data

# %%
# Splitting data indexes

tr_ind, val_ind = train_test_split(list(range(len(final))) ,test_size = 0.33, random_state = 23)
print(len(tr_ind), len(val_ind))
# Out:
# 1209265 595609

# %% [markdown]
# <h1> 5. Featurization : word2vec

# %%
## Code adapted from (https://github.com/keras-team/keras/blob/master/examples/pretrained_word_embeddings.py)
# Vectorize the text 

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical

#MAX_NUM_WORDS = 100000
MAX_SEQUENCE_LENGTH = 220
#tokenizer = Tokenizer(num_words=MAX_NUM_WORDS)
tokenizer = Tokenizer()
tokenizer.fit_on_texts(final['preprocessed_data'])
sequences = tokenizer.texts_to_sequences(final['preprocessed_data'][tr_ind])

word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))

train_data = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH) # fixed the length of words in a row and use padding for that
#train_labels = to_categorical(np.asarray(y_train))

cv_data=pad_sequences(tokenizer.texts_to_sequences(final['preprocessed_data'][val_ind]), maxlen=MAX_SEQUENCE_LENGTH)
#cv_labels=to_categorical(np.asarray(y_cv))

print(train_data.shape)

print(cv_data.shape)
# Out:
# Found 309240 unique tokens.
# (1209265, 220)
# (595609, 220)

# %%
#tokenizing test data
sequences_test= tokenizer.texts_to_sequences(test_data['comment_text'])

test_data = pad_sequences(sequences_test, maxlen=MAX_SEQUENCE_LENGTH)

# %%
# use glove.840B.300d.txt for word embeddings
#GloVe is an unsupervised learning algorithm for obtaining vector representations for words. 
#Training is performed on aggregated global word-word co-occurrence statistics from a corpus, and the resulting representations showcase interesting linear substructures of the word vector space.

embeddings_index_glove = {}
embeddings_index_crawl = {}

#EMBEDDING_FILE="../input/glove840b300dtxt/glove.840B.300d.txt"
#EMBEDDING_FILE_CRAWL='../data/crawl-300d-2M.vec'
EMBEDDING_FILE_GLOVE='../data/glove.840B.300d.txt'
    
EMBEDDINGS_DIMENSION=300
f = open(EMBEDDING_FILE_GLOVE,encoding="utf-8") 
for line in f:
    values = line.split(' ')
    word = values[0] ## The first entry is the word
    coefs = np.asarray(values[1:], dtype='float32') ## These are the vecotrs representing the embedding for the word
    embeddings_index_glove[word] = coefs
f.close()


#f = open(EMBEDDING_FILE_CRAWL,encoding="utf-8") 
#for line in f:
 #   values = line.split(' ')
  #  word = values[0] ## The first entry is the word
   # coefs = np.asarray(values[1:]) ## These are the vecotrs representing the embedding for the word
    #embeddings_index_crawl[word] = coefs
#f.close()



print('data loaded')
# Out:
# data loaded

# %%
embeddings_index_glove["happy"][:300]
# Out:
# array([ 0.036775 ,  0.40917  , -0.52141  , -0.067184 ,  0.087702 ,
#        -0.048564 ,  0.40947  , -0.42818  ,  0.19304  ,  2.3925   ,
#        -0.11441  , -0.22952  , -0.16061  ,  0.035533 , -0.53179  ,
#         0.19764  , -0.48827  ,  0.57439  , -0.064301 ,  0.47053  ,
#        -0.29647  , -0.15927  , -0.052798 ,  0.10121  , -0.054461 ,
#         0.036129 , -0.16118  , -0.34139  ,  0.45834  , -0.20144  ,
#        -0.29067  , -0.51888  , -0.062106 ,  0.14084  ,  0.016413 ,
#         0.050826 ,  0.13243  , -0.033663 , -0.42228  , -0.30086  ,
#         0.06202  ,  0.26338  ,  0.077223 ,  0.27307  ,  0.13392  ,
#         0.30183  , -0.16546  ,  0.057011 , -0.0034585, -0.071113 ,
#        -0.27287  , -0.10297  ,  0.07457  , -0.32104  ,  0.36696  ,
#         0.27051  , -0.15776  ,  0.2978   , -0.18988  ,  0.097477 ,
#         0.035665 , -0.49749  , -0.52759  , -0.046148 ,  0.021715 ,
#        -0.11047  , -0.18007  ,  0.20295  ,  0.15254  , -0.045976 ,
#        -0.21846  , -0.066865 , -0.21355  ,  0.017509 ,  0.66474  ,
#         0.25527  ,  0.24864  , -0.094851 , -0.012857 ,  0.46896  ,
#         0.052031 ,  0.62488  , -0.12662  ,  0.063972 , -0.15719  ,
#        -0.45907  ,  0.32286  , -0.17502  ,  0.64181  ,  0.091587 ,
#        -0.075871 ,  0.11718  , -0.13864  ,  0.24951  , -0.40664  ,
#         0.08845  , -0.29196  , -0.51624  , -0.074847 , -0.012822 ,
#        -0.088844 , -0.19935  ,  0.052734 , -0.13588  ,  0.231    ,
#        -0.34368  ,  0.30607  , -0.21223  ,  0.08178  ,  0.10097  ,
#         0.33585  , -0.17491  ,  0.019115 ,  0.15998  ,  0.38803  ,
#        -0.35932  ,  0.31682  , -0.18614  ,  0.11732  , -0.068517 ,
#         0.50785  , -0.0035486,  0.20069  ,  0.25218  ,  0.38309  ,
#         0.19359  ,  0.43857  , -0.29954  , -0.14219  ,  0.087962 ,
#        -0.14229  ,  0.10075  , -0.58986  , -0.12672  ,  0.036944 ,
#        -0.050421 , -0.19875  , -0.051368 , -0.023402 ,  0.08744  ,
#        -2.4938   ,  0.15427  ,  0.12373  , -0.0086429, -0.17007  ,
#        -0.519    , -0.29962  ,  0.24369  , -0.20535  , -0.24942  ,
#        -0.079362 ,  0.40986  , -0.10753  ,  0.098907 , -0.063449 ,
#         0.05373  ,  0.26206  ,  0.13207  , -0.067694 , -0.56168  ,
#        -0.18867  ,  0.14453  , -0.22469  , -0.28404  ,  0.20909  ,
#        -0.46989  ,  0.30992  , -0.13283  ,  0.041392 ,  0.11146  ,
#         0.17015  , -0.059407 , -0.16098  , -0.2211   , -0.0035877,
#        -0.22357  , -0.01852  , -0.23026  , -0.18824  ,  0.32997  ,
#         0.16287  , -0.52067  ,  0.17308  , -0.024264 , -0.041321 ,
#        -0.3241   , -0.44122  , -0.11114  ,  0.22684  , -0.10883  ,
#        -0.1278   , -0.16696  ,  0.051048 , -0.12131  ,  0.18038  ,
#         0.19793  ,  0.134    , -0.37113  ,  0.36008  ,  0.092685 ,
#        -0.30263  ,  0.16565  , -0.10863  , -0.29565  ,  0.26143  ,
#         0.13369  , -0.090181 ,  0.021989 , -0.093353 , -0.20325  ,
#        -0.2008   ,  0.20721  ,  0.17208  , -0.20199  ,  0.043315 ,
#         0.17768  ,  0.57448  , -0.45917  , -0.077197 ,  0.12051  ,
#         0.07209  , -0.095313 ,  0.10973  ,  0.22375  ,  0.045804 ,
#        -0.13573  ,  0.14041  , -0.11364  , -0.46605  , -0.43262  ,
#        -0.058678 ,  0.19043  , -0.40867  ,  0.30509  ,  0.18542  ,
#         0.095309 , -0.42329  , -0.15225  , -0.13827  ,  0.18119  ,
#         0.14755  , -0.053628 ,  0.031298 ,  0.65695  , -0.1717   ,
#         0.23649  , -0.34742  , -0.17438  , -0.085304 ,  0.37687  ,
#         0.21322  , -0.13184  , -0.35197  , -0.14072  ,  0.2332   ,
#         0.21014  , -0.14763  ,  0.047515 , -0.27979  ,  0.090331 ,
#        -0.15565  ,  0.42803  , -0.019297 ,  0.012198 ,  0.036031 ,
#        -0.10396  ,  0.11014  ,  0.13458  ,  0.2775   ,  0.36225  ,
#        -0.35591  , -0.16877  , -0.41201  ,  0.070133 , -0.27769  ,
#         0.13739  , -0.057831 ,  0.19277  ,  0.11131  ,  0.53696  ,
#         0.0093424, -0.26107  , -0.38663  ,  0.040653 ,  0.18617  ,
#         0.26312  ,  0.12212  , -0.030012 ,  0.096286 ,  0.47376  ,
#        -0.21633  ,  0.10798  , -0.17703  ,  0.22116  ,  0.6726   ,
#         0.065036 , -0.017414 , -0.048585 , -0.090863 ,  0.28591  ],
#       dtype=float32)

# %%
# prepare embedding matrix for all unique toxens in preprocessed text
from keras.layers import Embedding
from keras.initializers import Constant

# My system is not taking 600 dimensions of embedding, so sticking to Glove embeddings only.

## EMBEDDINGS_DIMENSION =  ## dimension of glove vectors
embedding_matrix_glove = np.zeros((len(tokenizer.word_index) + 1,
                                 EMBEDDINGS_DIMENSION))
num_words_in_embedding = 0
for word, i in tokenizer.word_index.items():
    embedding_vector = embeddings_index_glove.get(word)
    if embedding_vector is not None:
        num_words_in_embedding += 1
        # words not found in embedding index will be all-zeros.
        embedding_matrix_glove[i] = embedding_vector


print(embedding_matrix_glove.shape)




## EMBEDDINGS_DIMENSION =  ## dimension of glove vectors
#embedding_matrix_crawl = np.zeros((len(tokenizer.word_index)+1 ,
#                                 EMBEDDINGS_DIMENSION))
#num_words_in_embedding = 0
#for word, i in tokenizer.word_index.items():
#    embedding_vector = embeddings_index_crawl.get(word)
#    if embedding_vector is not None:
#        num_words_in_embedding += 1
#        # words not found in embedding index will be all-zeros.
#        embedding_matrix_crawl[i] = embedding_vector[:300]


#print(embedding_matrix_crawl.shape)
# Out:
# (309241, 300)

# %%
#embedding_matrix = np.concatenate([embedding_matrix_glove,embedding_matrix_crawl], axis =-1)
embedding_matrix = embedding_matrix_glove
print(embedding_matrix.shape)
#del embedding_matrix_crawl
del embedding_matrix_glove
import gc
gc.collect()
# Out:
# (309241, 300)
# 67

# %% [markdown]
# ## Adding attention layer
# Source: https://www.kaggle.com/christofhenkel/keras-baseline-lstm-attention-5-fold

# %%
from keras import backend as K
from keras.engine.topology import Layer
from keras import initializers, regularizers, constraints, optimizers, layers

class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = initializers.get('glorot_uniform')

        self.W_regularizer = regularizers.get(W_regularizer)
        self.b_regularizer = regularizers.get(b_regularizer)

        self.W_constraint = constraints.get(W_constraint)
        self.b_constraint = constraints.get(b_constraint)

        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight((input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight((input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                        K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a
        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0],  self.features_dim

# %% [markdown]
# # 6. Define and train a LSTM Neural Net for classifying toxic comments

# %%
def custom_loss(y_true, y_pred):
    return binary_crossentropy(K.reshape(y_true[:,0],(-1,1)), y_pred) * y_true[:,1]

# %% [markdown]
# ## Model Architecture

# %%
# Model Architecture
from keras.layers import Input, Dense, Embedding, SpatialDropout1D, add, concatenate
from keras.layers import CuDNNLSTM, Bidirectional, GlobalMaxPooling1D, GlobalAveragePooling1D

def build_model(embedding_matrix, num_aux_targets,loss_weight):
    """ Model Architecture"""
    
    LSTM_UNITS = 128
    DENSE_HIDDEN_UNITS = 4 * LSTM_UNITS
    

    sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,))
    embedding_layer = Embedding(*embedding_matrix.shape,
                                weights=[embedding_matrix],
                                trainable=False)
    x = embedding_layer(sequence_input)
    x = SpatialDropout1D(0.3)(x)
    x = Bidirectional(CuDNNLSTM(LSTM_UNITS, return_sequences=True))(x)
    x = Bidirectional(CuDNNLSTM(LSTM_UNITS, return_sequences=True))(x)
    X = Attention(MAX_SEQUENCE_LENGTH)(x)

    hidden = concatenate([        
        GlobalMaxPooling1D()(x),
        GlobalAveragePooling1D()(x),
    ])
    hidden = add([hidden, Dense(DENSE_HIDDEN_UNITS, activation='relu')(hidden)])
    hidden = add([hidden, Dense(DENSE_HIDDEN_UNITS, activation='relu')(hidden)])
    
    result = Dense(1, activation='sigmoid')(hidden)
    aux_result = Dense(num_aux_targets, activation='sigmoid')(result)
    
   
    # Compile model.
    print('compiling model')
    model = Model(inputs=sequence_input, outputs=[result, aux_result])
    model.compile(loss=[custom_loss,'binary_crossentropy'],loss_weights=[loss_weight, 1.0],
              optimizer='adam')



    return(model)

# %%
import tensorflow as tf
gpu_options = tf.GPUOptions(allow_growth=True)
session = tf.InteractiveSession(config=tf.ConfigProto(gpu_options=gpu_options))

# %%
# Build Model
print(y_aux_data.shape[-1])
build_model(embedding_matrix, y_aux_data.shape[-1], loss_weight).summary()
# Out:
# 7
# WARNING: Logging before flag parsing goes to stderr.
# W0120 13:19:13.779358  1620 deprecation_wrapper.py:119] From C:\Users\mukesh\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0120 13:19:13.781349  1620 deprecation_wrapper.py:119] From C:\Users\mukesh\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0120 13:19:13.789355  1620 deprecation_wrapper.py:119] From C:\Users\mukesh\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0120 13:19:13.801304  1620 deprecation_wrapper.py:119] From C:\Users\mukesh\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0120 13:19:13.803293  1620 deprecation_wrapper.py:119] From C:\Users\mukesh\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# W0120 13:19:14.548366  1620 deprecation.py:506] From C:\Users\mukesh\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# compiling model
# W0120 13:19:17.688891  1620 deprecation_wrapper.py:119] From C:\Users\mukesh\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0120 13:19:17.728767  1620 deprecation.py:323] From C:\Users\mukesh\Anaconda3\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 220)          0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 220, 300)     92772300    input_1[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_1 (SpatialDro (None, 220, 300)     0           embedding_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 220, 256)     440320      spatial_dropout1d_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 220, 256)     395264      bidirectional_1[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_1 (GlobalM (None, 256)          0           bidirectional_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 256)          0           bidirectional_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 512)          0           global_max_pooling1d_1[0][0]
#                                                                  global_average_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          262656      concatenate_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 512)          0           concatenate_1[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          262656      add_1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 512)          0           add_1[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            513         add_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 7)            14          dense_3[0][0]
# ==================================================================================================
# Total params: 94,133,723
# Trainable params: 1,361,423
# Non-trainable params: 92,772,300
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training the model

# %%
# train the model
checkpoint_predictions = []
val_preds=[]
weights = []
NUM_MODELS=2
NUM_EPOCHS = 4
BATCH_SIZE = 512

# Run the model
import keras
if os.path.exists('../input/mymodel/my_model_new.h5'):
    print("Loading model")
    model = keras.models.load_model('../input/mymodel/my_model_new.h5')
else:
    model = build_model(embedding_matrix,y_aux_data.shape[-1], loss_weight)
    model.fit(
        train_data,
        [y_data[tr_ind], y_aux_data[tr_ind]],
        batch_size=BATCH_SIZE,
        epochs=NUM_EPOCHS,
        verbose=1,
        validation_data=(cv_data, [y_data[val_ind], y_aux_data[val_ind]]),
        callbacks=[
            LearningRateScheduler(lambda epoch: 1e-3 * (0.6 ** 1))
        ])
# Out:
# compiling model
# Train on 1209265 samples, validate on 595609 samples
# Epoch 1/4
#   57344/1209265 [>.............................] - ETA: 2:41:28 - loss: 1.2630 - dense_7_loss: 0.1757 - dense_8_loss: 0.69 - ETA: 1:25:36 - loss: 1.2177 - dense_7_loss: 0.1623 - dense_8_loss: 0.69 - ETA: 1:00:12 - loss: 1.1815 - dense_7_loss: 0.1514 - dense_8_loss: 0.69 - ETA: 47:30 - loss: 1.1770 - dense_7_loss: 0.1502 - dense_8_loss: 0.6950 - ETA: 39:53 - loss: 1.1599 - dense_7_loss: 0.1450 - dense_8_loss: 0.69 - ETA: 34:47 - loss: 1.1466 - dense_7_loss: 0.1410 - dense_8_loss: 0.69 - ETA: 31:12 - loss: 1.1481 - dense_7_loss: 0.1416 - dense_8_loss: 0.69 - ETA: 28:29 - loss: 1.1293 - dense_7_loss: 0.1358 - dense_8_loss: 0.69 - ETA: 26:23 - loss: 1.1257 - dense_7_loss: 0.1348 - dense_8_loss: 0.69 - ETA: 24:42 - loss: 1.1195 - dense_7_loss: 0.1329 - dense_8_loss: 0.69 - ETA: 23:18 - loss: 1.1155 - dense_7_loss: 0.1317 - dense_8_loss: 0.69 - ETA: 22:09 - loss: 1.1118 - dense_7_loss: 0.1306 - dense_8_loss: 0.69 - ETA: 21:10 - loss: 1.1118 - dense_7_loss: 0.1306 - dense_8_loss: 0.69 - ETA: 20:22 - loss: 1.1084 - dense_7_loss: 0.1296 - dense_8_loss: 0.69 - ETA: 19:36 - loss: 1.1058 - dense_7_loss: 0.1289 - dense_8_loss: 0.69 - ETA: 18:58 - loss: 1.1050 - dense_7_loss: 0.1287 - dense_8_loss: 0.69 - ETA: 18:24 - loss: 1.1052 - dense_7_loss: 0.1288 - dense_8_loss: 0.69 - ETA: 17:54 - loss: 1.1084 - dense_7_loss: 0.1299 - dense_8_loss: 0.69 - ETA: 17:28 - loss: 1.1065 - dense_7_loss: 0.1293 - dense_8_loss: 0.69 - ETA: 17:04 - loss: 1.1058 - dense_7_loss: 0.1292 - dense_8_loss: 0.69 - ETA: 16:43 - loss: 1.1052 - dense_7_loss: 0.1291 - dense_8_loss: 0.69 - ETA: 16:22 - loss: 1.1046 - dense_7_loss: 0.1289 - dense_8_loss: 0.69 - ETA: 16:04 - loss: 1.1000 - dense_7_loss: 0.1275 - dense_8_loss: 0.69 - ETA: 15:47 - loss: 1.1008 - dense_7_loss: 0.1278 - dense_8_loss: 0.69 - ETA: 15:32 - loss: 1.0988 - dense_7_loss: 0.1273 - dense_8_loss: 0.69 - ETA: 15:18 - loss: 1.1004 - dense_7_loss: 0.1278 - dense_8_loss: 0.69 - ETA: 15:05 - loss: 1.1005 - dense_7_loss: 0.1279 - dense_8_loss: 0.69 - ETA: 14:52 - loss: 1.0967 - dense_7_loss: 0.1268 - dense_8_loss: 0.68 - ETA: 14:41 - loss: 1.0977 - dense_7_loss: 0.1271 - dense_8_loss: 0.68 - ETA: 14:30 - loss: 1.0974 - dense_7_loss: 0.1271 - dense_8_loss: 0.68 - ETA: 14:20 - loss: 1.0957 - dense_7_loss: 0.1266 - dense_8_loss: 0.68 - ETA: 14:10 - loss: 1.0966 - dense_7_loss: 0.1270 - dense_8_loss: 0.68 - ETA: 14:01 - loss: 1.0959 - dense_7_loss: 0.1268 - dense_8_loss: 0.68 - ETA: 13:53 - loss: 1.0957 - dense_7_loss: 0.1268 - dense_8_loss: 0.68 - ETA: 13:45 - loss: 1.0951 - dense_7_loss: 0.1266 - dense_8_loss: 0.68 - ETA: 13:38 - loss: 1.0947 - dense_7_loss: 0.1266 - dense_8_loss: 0.68 - ETA: 13:30 - loss: 1.0942 - dense_7_loss: 0.1264 - dense_8_loss: 0.68 - ETA: 13:24 - loss: 1.0945 - dense_7_loss: 0.1266 - dense_8_loss: 0.68 - ETA: 13:17 - loss: 1.0925 - dense_7_loss: 0.1260 - dense_8_loss: 0.68 - ETA: 13:11 - loss: 1.0919 - dense_7_loss: 0.1259 - dense_8_loss: 0.68 - ETA: 13:06 - loss: 1.0897 - dense_7_loss: 0.1253 - dense_8_loss: 0.68 - ETA: 12:59 - loss: 1.0879 - dense_7_loss: 0.1247 - dense_8_loss: 0.68 - ETA: 12:54 - loss: 1.0884 - dense_7_loss: 0.1249 - dense_8_loss: 0.68 - ETA: 12:49 - loss: 1.0865 - dense_7_loss: 0.1244 - dense_8_loss: 0.68 - ETA: 12:44 - loss: 1.0848 - dense_7_loss: 0.1239 - dense_8_loss: 0.68 - ETA: 12:39 - loss: 1.0849 - dense_7_loss: 0.1240 - dense_8_loss: 0.68 - ETA: 12:35 - loss: 1.0828 - dense_7_loss: 0.1234 - dense_8_loss: 0.68 - ETA: 12:31 - loss: 1.0815 - dense_7_loss: 0.1230 - dense_8_loss: 0.68 - ETA: 12:26 - loss: 1.0794 - dense_7_loss: 0.1224 - dense_8_loss: 0.68 - ETA: 12:23 - loss: 1.0797 - dense_7_loss: 0.1225 - dense_8_loss: 0.68 - ETA: 12:19 - loss: 1.0789 - dense_7_loss: 0.1223 - dense_8_loss: 0.68 - ETA: 12:15 - loss: 1.0786 - dense_7_loss: 0.1223 - dense_8_loss: 0.68 - ETA: 12:12 - loss: 1.0782 - dense_7_loss: 0.1222 - dense_8_loss: 0.68 - ETA: 12:08 - loss: 1.0772 - dense_7_loss: 0.1219 - dense_8_loss: 0.68 - ETA: 12:05 - loss: 1.0766 - dense_7_loss: 0.1218 - de ...
#  115712/1209265 [=>............................] - ETA: 10:29 - loss: 1.0223 - dense_7_loss: 0.1074 - dense_8_loss: 0.67 - ETA: 10:28 - loss: 1.0210 - dense_7_loss: 0.1071 - dense_8_loss: 0.67 - ETA: 10:27 - loss: 1.0205 - dense_7_loss: 0.1070 - dense_8_loss: 0.67 - ETA: 10:26 - loss: 1.0198 - dense_7_loss: 0.1068 - dense_8_loss: 0.67 - ETA: 10:25 - loss: 1.0190 - dense_7_loss: 0.1066 - dense_8_loss: 0.67 - ETA: 10:24 - loss: 1.0184 - dense_7_loss: 0.1065 - dense_8_loss: 0.67 - ETA: 10:23 - loss: 1.0183 - dense_7_loss: 0.1065 - dense_8_loss: 0.67 - ETA: 10:22 - loss: 1.0171 - dense_7_loss: 0.1061 - dense_8_loss: 0.67 - ETA: 10:21 - loss: 1.0164 - dense_7_loss: 0.1060 - dense_8_loss: 0.67 - ETA: 10:21 - loss: 1.0155 - dense_7_loss: 0.1057 - dense_8_loss: 0.67 - ETA: 10:20 - loss: 1.0151 - dense_7_loss: 0.1056 - dense_8_loss: 0.67 - ETA: 10:19 - loss: 1.0143 - dense_7_loss: 0.1054 - dense_8_loss: 0.67 - ETA: 10:18 - loss: 1.0132 - dense_7_loss: 0.1051 - dense_8_loss: 0.67 - ETA: 10:17 - loss: 1.0119 - dense_7_loss: 0.1048 - dense_8_loss: 0.67 - ETA: 10:16 - loss: 1.0104 - dense_7_loss: 0.1043 - dense_8_loss: 0.67 - ETA: 10:16 - loss: 1.0096 - dense_7_loss: 0.1041 - dense_8_loss: 0.67 - ETA: 10:15 - loss: 1.0093 - dense_7_loss: 0.1041 - dense_8_loss: 0.67 - ETA: 10:14 - loss: 1.0087 - dense_7_loss: 0.1039 - dense_8_loss: 0.67 - ETA: 10:13 - loss: 1.0080 - dense_7_loss: 0.1038 - dense_8_loss: 0.67 - ETA: 10:13 - loss: 1.0073 - dense_7_loss: 0.1036 - dense_8_loss: 0.67 - ETA: 10:12 - loss: 1.0067 - dense_7_loss: 0.1034 - dense_8_loss: 0.67 - ETA: 10:11 - loss: 1.0055 - dense_7_loss: 0.1031 - dense_8_loss: 0.67 - ETA: 10:10 - loss: 1.0047 - dense_7_loss: 0.1029 - dense_8_loss: 0.67 - ETA: 10:10 - loss: 1.0035 - dense_7_loss: 0.1026 - dense_8_loss: 0.67 - ETA: 10:09 - loss: 1.0026 - dense_7_loss: 0.1024 - dense_8_loss: 0.67 - ETA: 10:08 - loss: 1.0024 - dense_7_loss: 0.1023 - dense_8_loss: 0.67 - ETA: 10:07 - loss: 1.0014 - dense_7_loss: 0.1021 - dense_8_loss: 0.67 - ETA: 10:07 - loss: 1.0007 - dense_7_loss: 0.1019 - dense_8_loss: 0.67 - ETA: 10:06 - loss: 1.0000 - dense_7_loss: 0.1017 - dense_8_loss: 0.67 - ETA: 10:05 - loss: 0.9994 - dense_7_loss: 0.1016 - dense_8_loss: 0.67 - ETA: 10:05 - loss: 0.9985 - dense_7_loss: 0.1013 - dense_8_loss: 0.67 - ETA: 10:04 - loss: 0.9976 - dense_7_loss: 0.1011 - dense_8_loss: 0.67 - ETA: 10:03 - loss: 0.9967 - dense_7_loss: 0.1008 - dense_8_loss: 0.67 - ETA: 10:03 - loss: 0.9967 - dense_7_loss: 0.1009 - dense_8_loss: 0.67 - ETA: 10:02 - loss: 0.9960 - dense_7_loss: 0.1007 - dense_8_loss: 0.67 - ETA: 10:01 - loss: 0.9953 - dense_7_loss: 0.1006 - dense_8_loss: 0.67 - ETA: 10:01 - loss: 0.9948 - dense_7_loss: 0.1004 - dense_8_loss: 0.67 - ETA: 10:00 - loss: 0.9942 - dense_7_loss: 0.1003 - dense_8_loss: 0.67 - ETA: 10:00 - loss: 0.9936 - dense_7_loss: 0.1001 - dense_8_loss: 0.67 - ETA: 9:59 - loss: 0.9925 - dense_7_loss: 0.0999 - dense_8_loss: 0.6721 - ETA: 9:58 - loss: 0.9916 - dense_7_loss: 0.0996 - dense_8_loss: 0.672 - ETA: 9:57 - loss: 0.9909 - dense_7_loss: 0.0994 - dense_8_loss: 0.671 - ETA: 9:57 - loss: 0.9907 - dense_7_loss: 0.0994 - dense_8_loss: 0.671 - ETA: 9:56 - loss: 0.9905 - dense_7_loss: 0.0994 - dense_8_loss: 0.671 - ETA: 9:56 - loss: 0.9898 - dense_7_loss: 0.0992 - dense_8_loss: 0.671 - ETA: 9:55 - loss: 0.9895 - dense_7_loss: 0.0992 - dense_8_loss: 0.671 - ETA: 9:54 - loss: 0.9891 - dense_7_loss: 0.0991 - dense_8_loss: 0.671 - ETA: 9:54 - loss: 0.9887 - dense_7_loss: 0.0990 - dense_8_loss: 0.671 - ETA: 9:53 - loss: 0.9882 - dense_7_loss: 0.0989 - dense_8_loss: 0.670 - ETA: 9:53 - loss: 0.9881 - dense_7_loss: 0.0989 - dense_8_loss: 0.670 - ETA: 9:52 - loss: 0.9874 - dense_7_loss: 0.0987 - dense_8_loss: 0.670 - ETA: 9:52 - loss: 0.9866 - dense_7_loss: 0.0985 - dense_8_loss: 0.670 - ETA: 9:51 - loss: 0.9862 - dense_7_loss: 0.0984 - dense_8_loss: 0.670 - ETA: 9:51 - loss: 0.9860 - dense_7_loss: 0.0984 - dense_8_loss: 0.670 - ETA: 9:50 - loss: 0.9857 - dense_7_loss: 0.0984 - dense_8_lo ...
#  174080/1209265 [===>..........................] - ETA: 9:22 - loss: 0.9587 - dense_7_loss: 0.0925 - dense_8_loss: 0.661 - ETA: 9:21 - loss: 0.9582 - dense_7_loss: 0.0924 - dense_8_loss: 0.661 - ETA: 9:21 - loss: 0.9578 - dense_7_loss: 0.0923 - dense_8_loss: 0.661 - ETA: 9:21 - loss: 0.9575 - dense_7_loss: 0.0923 - dense_8_loss: 0.661 - ETA: 9:20 - loss: 0.9570 - dense_7_loss: 0.0922 - dense_8_loss: 0.661 - ETA: 9:20 - loss: 0.9567 - dense_7_loss: 0.0921 - dense_8_loss: 0.661 - ETA: 9:19 - loss: 0.9562 - dense_7_loss: 0.0920 - dense_8_loss: 0.660 - ETA: 9:19 - loss: 0.9558 - dense_7_loss: 0.0919 - dense_8_loss: 0.660 - ETA: 9:19 - loss: 0.9551 - dense_7_loss: 0.0918 - dense_8_loss: 0.660 - ETA: 9:18 - loss: 0.9546 - dense_7_loss: 0.0916 - dense_8_loss: 0.660 - ETA: 9:18 - loss: 0.9542 - dense_7_loss: 0.0916 - dense_8_loss: 0.660 - ETA: 9:17 - loss: 0.9537 - dense_7_loss: 0.0914 - dense_8_loss: 0.660 - ETA: 9:17 - loss: 0.9533 - dense_7_loss: 0.0914 - dense_8_loss: 0.660 - ETA: 9:17 - loss: 0.9529 - dense_7_loss: 0.0913 - dense_8_loss: 0.660 - ETA: 9:16 - loss: 0.9525 - dense_7_loss: 0.0912 - dense_8_loss: 0.659 - ETA: 9:16 - loss: 0.9521 - dense_7_loss: 0.0911 - dense_8_loss: 0.659 - ETA: 9:15 - loss: 0.9518 - dense_7_loss: 0.0910 - dense_8_loss: 0.659 - ETA: 9:15 - loss: 0.9512 - dense_7_loss: 0.0909 - dense_8_loss: 0.659 - ETA: 9:15 - loss: 0.9509 - dense_7_loss: 0.0909 - dense_8_loss: 0.659 - ETA: 9:14 - loss: 0.9506 - dense_7_loss: 0.0908 - dense_8_loss: 0.659 - ETA: 9:14 - loss: 0.9501 - dense_7_loss: 0.0907 - dense_8_loss: 0.659 - ETA: 9:14 - loss: 0.9496 - dense_7_loss: 0.0906 - dense_8_loss: 0.658 - ETA: 9:13 - loss: 0.9494 - dense_7_loss: 0.0905 - dense_8_loss: 0.658 - ETA: 9:13 - loss: 0.9490 - dense_7_loss: 0.0905 - dense_8_loss: 0.658 - ETA: 9:12 - loss: 0.9487 - dense_7_loss: 0.0904 - dense_8_loss: 0.658 - ETA: 9:12 - loss: 0.9482 - dense_7_loss: 0.0903 - dense_8_loss: 0.658 - ETA: 9:12 - loss: 0.9479 - dense_7_loss: 0.0903 - dense_8_loss: 0.658 - ETA: 9:11 - loss: 0.9475 - dense_7_loss: 0.0902 - dense_8_loss: 0.658 - ETA: 9:11 - loss: 0.9472 - dense_7_loss: 0.0901 - dense_8_loss: 0.658 - ETA: 9:11 - loss: 0.9466 - dense_7_loss: 0.0900 - dense_8_loss: 0.657 - ETA: 9:10 - loss: 0.9463 - dense_7_loss: 0.0899 - dense_8_loss: 0.657 - ETA: 9:10 - loss: 0.9461 - dense_7_loss: 0.0899 - dense_8_loss: 0.657 - ETA: 9:10 - loss: 0.9459 - dense_7_loss: 0.0899 - dense_8_loss: 0.657 - ETA: 9:09 - loss: 0.9455 - dense_7_loss: 0.0898 - dense_8_loss: 0.657 - ETA: 9:09 - loss: 0.9452 - dense_7_loss: 0.0898 - dense_8_loss: 0.657 - ETA: 9:08 - loss: 0.9450 - dense_7_loss: 0.0897 - dense_8_loss: 0.657 - ETA: 9:08 - loss: 0.9448 - dense_7_loss: 0.0897 - dense_8_loss: 0.656 - ETA: 9:08 - loss: 0.9446 - dense_7_loss: 0.0897 - dense_8_loss: 0.656 - ETA: 9:07 - loss: 0.9441 - dense_7_loss: 0.0896 - dense_8_loss: 0.656 - ETA: 9:07 - loss: 0.9437 - dense_7_loss: 0.0895 - dense_8_loss: 0.656 - ETA: 9:07 - loss: 0.9435 - dense_7_loss: 0.0895 - dense_8_loss: 0.656 - ETA: 9:06 - loss: 0.9430 - dense_7_loss: 0.0894 - dense_8_loss: 0.656 - ETA: 9:06 - loss: 0.9427 - dense_7_loss: 0.0893 - dense_8_loss: 0.656 - ETA: 9:05 - loss: 0.9422 - dense_7_loss: 0.0892 - dense_8_loss: 0.655 - ETA: 9:05 - loss: 0.9418 - dense_7_loss: 0.0891 - dense_8_loss: 0.655 - ETA: 9:05 - loss: 0.9413 - dense_7_loss: 0.0890 - dense_8_loss: 0.655 - ETA: 9:04 - loss: 0.9410 - dense_7_loss: 0.0889 - dense_8_loss: 0.655 - ETA: 9:04 - loss: 0.9407 - dense_7_loss: 0.0889 - dense_8_loss: 0.655 - ETA: 9:04 - loss: 0.9406 - dense_7_loss: 0.0889 - dense_8_loss: 0.655 - ETA: 9:03 - loss: 0.9402 - dense_7_loss: 0.0888 - dense_8_loss: 0.655 - ETA: 9:03 - loss: 0.9399 - dense_7_loss: 0.0888 - dense_8_loss: 0.655 - ETA: 9:03 - loss: 0.9397 - dense_7_loss: 0.0888 - dense_8_loss: 0.654 - ETA: 9:02 - loss: 0.9396 - dense_7_loss: 0.0888 - dense_8_loss: 0.654 - ETA: 9:02 - loss: 0.9391 - dense_7_loss: 0.0886 - dense_8_loss: 0.654 - ETA: 9:02 - loss: 0.9387 - dense_7_loss: 0.0886 - dense_8_los ...
#  232448/1209265 [====>.........................] - ETA: 8:42 - loss: 0.9207 - dense_7_loss: 0.0854 - dense_8_loss: 0.646 - ETA: 8:41 - loss: 0.9205 - dense_7_loss: 0.0854 - dense_8_loss: 0.646 - ETA: 8:41 - loss: 0.9203 - dense_7_loss: 0.0854 - dense_8_loss: 0.646 - ETA: 8:41 - loss: 0.9200 - dense_7_loss: 0.0854 - dense_8_loss: 0.646 - ETA: 8:40 - loss: 0.9198 - dense_7_loss: 0.0853 - dense_8_loss: 0.646 - ETA: 8:40 - loss: 0.9195 - dense_7_loss: 0.0853 - dense_8_loss: 0.645 - ETA: 8:40 - loss: 0.9192 - dense_7_loss: 0.0852 - dense_8_loss: 0.645 - ETA: 8:39 - loss: 0.9190 - dense_7_loss: 0.0852 - dense_8_loss: 0.645 - ETA: 8:39 - loss: 0.9188 - dense_7_loss: 0.0852 - dense_8_loss: 0.645 - ETA: 8:39 - loss: 0.9186 - dense_7_loss: 0.0851 - dense_8_loss: 0.645 - ETA: 8:38 - loss: 0.9186 - dense_7_loss: 0.0852 - dense_8_loss: 0.645 - ETA: 8:38 - loss: 0.9183 - dense_7_loss: 0.0851 - dense_8_loss: 0.645 - ETA: 8:38 - loss: 0.9182 - dense_7_loss: 0.0852 - dense_8_loss: 0.644 - ETA: 8:38 - loss: 0.9179 - dense_7_loss: 0.0851 - dense_8_loss: 0.644 - ETA: 8:37 - loss: 0.9178 - dense_7_loss: 0.0851 - dense_8_loss: 0.644 - ETA: 8:37 - loss: 0.9177 - dense_7_loss: 0.0851 - dense_8_loss: 0.644 - ETA: 8:37 - loss: 0.9175 - dense_7_loss: 0.0851 - dense_8_loss: 0.644 - ETA: 8:36 - loss: 0.9171 - dense_7_loss: 0.0850 - dense_8_loss: 0.644 - ETA: 8:36 - loss: 0.9168 - dense_7_loss: 0.0850 - dense_8_loss: 0.644 - ETA: 8:36 - loss: 0.9167 - dense_7_loss: 0.0850 - dense_8_loss: 0.644 - ETA: 8:35 - loss: 0.9165 - dense_7_loss: 0.0849 - dense_8_loss: 0.643 - ETA: 8:35 - loss: 0.9161 - dense_7_loss: 0.0849 - dense_8_loss: 0.643 - ETA: 8:35 - loss: 0.9159 - dense_7_loss: 0.0849 - dense_8_loss: 0.643 - ETA: 8:34 - loss: 0.9157 - dense_7_loss: 0.0848 - dense_8_loss: 0.643 - ETA: 8:34 - loss: 0.9156 - dense_7_loss: 0.0849 - dense_8_loss: 0.643 - ETA: 8:34 - loss: 0.9154 - dense_7_loss: 0.0848 - dense_8_loss: 0.643 - ETA: 8:33 - loss: 0.9152 - dense_7_loss: 0.0848 - dense_8_loss: 0.643 - ETA: 8:33 - loss: 0.9150 - dense_7_loss: 0.0848 - dense_8_loss: 0.642 - ETA: 8:33 - loss: 0.9147 - dense_7_loss: 0.0847 - dense_8_loss: 0.642 - ETA: 8:32 - loss: 0.9146 - dense_7_loss: 0.0847 - dense_8_loss: 0.642 - ETA: 8:32 - loss: 0.9145 - dense_7_loss: 0.0847 - dense_8_loss: 0.642 - ETA: 8:32 - loss: 0.9143 - dense_7_loss: 0.0847 - dense_8_loss: 0.642 - ETA: 8:32 - loss: 0.9140 - dense_7_loss: 0.0847 - dense_8_loss: 0.642 - ETA: 8:31 - loss: 0.9138 - dense_7_loss: 0.0847 - dense_8_loss: 0.642 - ETA: 8:31 - loss: 0.9136 - dense_7_loss: 0.0846 - dense_8_loss: 0.642 - ETA: 8:31 - loss: 0.9133 - dense_7_loss: 0.0846 - dense_8_loss: 0.641 - ETA: 8:30 - loss: 0.9130 - dense_7_loss: 0.0845 - dense_8_loss: 0.641 - ETA: 8:30 - loss: 0.9127 - dense_7_loss: 0.0845 - dense_8_loss: 0.641 - ETA: 8:30 - loss: 0.9124 - dense_7_loss: 0.0844 - dense_8_loss: 0.641 - ETA: 8:29 - loss: 0.9121 - dense_7_loss: 0.0844 - dense_8_loss: 0.641 - ETA: 8:29 - loss: 0.9117 - dense_7_loss: 0.0843 - dense_8_loss: 0.641 - ETA: 8:29 - loss: 0.9116 - dense_7_loss: 0.0843 - dense_8_loss: 0.641 - ETA: 8:29 - loss: 0.9114 - dense_7_loss: 0.0843 - dense_8_loss: 0.641 - ETA: 8:28 - loss: 0.9112 - dense_7_loss: 0.0842 - dense_8_loss: 0.640 - ETA: 8:28 - loss: 0.9109 - dense_7_loss: 0.0842 - dense_8_loss: 0.640 - ETA: 8:28 - loss: 0.9106 - dense_7_loss: 0.0841 - dense_8_loss: 0.640 - ETA: 8:27 - loss: 0.9103 - dense_7_loss: 0.0841 - dense_8_loss: 0.640 - ETA: 8:27 - loss: 0.9100 - dense_7_loss: 0.0840 - dense_8_loss: 0.640 - ETA: 8:27 - loss: 0.9099 - dense_7_loss: 0.0840 - dense_8_loss: 0.640 - ETA: 8:26 - loss: 0.9098 - dense_7_loss: 0.0840 - dense_8_loss: 0.640 - ETA: 8:26 - loss: 0.9097 - dense_7_loss: 0.0841 - dense_8_loss: 0.639 - ETA: 8:26 - loss: 0.9094 - dense_7_loss: 0.0840 - dense_8_loss: 0.639 - ETA: 8:26 - loss: 0.9092 - dense_7_loss: 0.0840 - dense_8_loss: 0.639 - ETA: 8:25 - loss: 0.9089 - dense_7_loss: 0.0839 - dense_8_loss: 0.639 - ETA: 8:25 - loss: 0.9087 - dense_7_loss: 0.0839 - dense_8_los ...
#  290816/1209265 [======>.......................] - ETA: 8:07 - loss: 0.8953 - dense_7_loss: 0.0821 - dense_8_loss: 0.631 - ETA: 8:07 - loss: 0.8951 - dense_7_loss: 0.0821 - dense_8_loss: 0.631 - ETA: 8:07 - loss: 0.8948 - dense_7_loss: 0.0821 - dense_8_loss: 0.631 - ETA: 8:07 - loss: 0.8945 - dense_7_loss: 0.0820 - dense_8_loss: 0.631 - ETA: 8:06 - loss: 0.8943 - dense_7_loss: 0.0820 - dense_8_loss: 0.631 - ETA: 8:06 - loss: 0.8941 - dense_7_loss: 0.0819 - dense_8_loss: 0.631 - ETA: 8:06 - loss: 0.8939 - dense_7_loss: 0.0819 - dense_8_loss: 0.631 - ETA: 8:05 - loss: 0.8937 - dense_7_loss: 0.0819 - dense_8_loss: 0.630 - ETA: 8:05 - loss: 0.8935 - dense_7_loss: 0.0819 - dense_8_loss: 0.630 - ETA: 8:05 - loss: 0.8932 - dense_7_loss: 0.0818 - dense_8_loss: 0.630 - ETA: 8:05 - loss: 0.8930 - dense_7_loss: 0.0818 - dense_8_loss: 0.630 - ETA: 8:04 - loss: 0.8928 - dense_7_loss: 0.0818 - dense_8_loss: 0.630 - ETA: 8:04 - loss: 0.8926 - dense_7_loss: 0.0818 - dense_8_loss: 0.630 - ETA: 8:04 - loss: 0.8924 - dense_7_loss: 0.0818 - dense_8_loss: 0.630 - ETA: 8:03 - loss: 0.8922 - dense_7_loss: 0.0817 - dense_8_loss: 0.630 - ETA: 8:03 - loss: 0.8919 - dense_7_loss: 0.0817 - dense_8_loss: 0.629 - ETA: 8:03 - loss: 0.8916 - dense_7_loss: 0.0816 - dense_8_loss: 0.629 - ETA: 8:03 - loss: 0.8913 - dense_7_loss: 0.0816 - dense_8_loss: 0.629 - ETA: 8:02 - loss: 0.8911 - dense_7_loss: 0.0815 - dense_8_loss: 0.629 - ETA: 8:02 - loss: 0.8909 - dense_7_loss: 0.0815 - dense_8_loss: 0.629 - ETA: 8:02 - loss: 0.8907 - dense_7_loss: 0.0815 - dense_8_loss: 0.629 - ETA: 8:01 - loss: 0.8904 - dense_7_loss: 0.0814 - dense_8_loss: 0.629 - ETA: 8:01 - loss: 0.8902 - dense_7_loss: 0.0814 - dense_8_loss: 0.628 - ETA: 8:01 - loss: 0.8899 - dense_7_loss: 0.0814 - dense_8_loss: 0.628 - ETA: 8:01 - loss: 0.8897 - dense_7_loss: 0.0813 - dense_8_loss: 0.628 - ETA: 8:00 - loss: 0.8895 - dense_7_loss: 0.0813 - dense_8_loss: 0.628 - ETA: 8:00 - loss: 0.8893 - dense_7_loss: 0.0813 - dense_8_loss: 0.628 - ETA: 8:00 - loss: 0.8892 - dense_7_loss: 0.0813 - dense_8_loss: 0.628 - ETA: 7:59 - loss: 0.8891 - dense_7_loss: 0.0813 - dense_8_loss: 0.628 - ETA: 7:59 - loss: 0.8889 - dense_7_loss: 0.0813 - dense_8_loss: 0.628 - ETA: 7:59 - loss: 0.8887 - dense_7_loss: 0.0813 - dense_8_loss: 0.627 - ETA: 7:59 - loss: 0.8886 - dense_7_loss: 0.0813 - dense_8_loss: 0.627 - ETA: 7:58 - loss: 0.8885 - dense_7_loss: 0.0813 - dense_8_loss: 0.627 - ETA: 7:58 - loss: 0.8883 - dense_7_loss: 0.0812 - dense_8_loss: 0.627 - ETA: 7:58 - loss: 0.8880 - dense_7_loss: 0.0812 - dense_8_loss: 0.627 - ETA: 7:57 - loss: 0.8877 - dense_7_loss: 0.0811 - dense_8_loss: 0.627 - ETA: 7:57 - loss: 0.8875 - dense_7_loss: 0.0811 - dense_8_loss: 0.627 - ETA: 7:57 - loss: 0.8874 - dense_7_loss: 0.0811 - dense_8_loss: 0.627 - ETA: 7:57 - loss: 0.8872 - dense_7_loss: 0.0811 - dense_8_loss: 0.626 - ETA: 7:56 - loss: 0.8871 - dense_7_loss: 0.0811 - dense_8_loss: 0.626 - ETA: 7:56 - loss: 0.8868 - dense_7_loss: 0.0810 - dense_8_loss: 0.626 - ETA: 7:56 - loss: 0.8865 - dense_7_loss: 0.0810 - dense_8_loss: 0.626 - ETA: 7:56 - loss: 0.8862 - dense_7_loss: 0.0809 - dense_8_loss: 0.626 - ETA: 7:55 - loss: 0.8860 - dense_7_loss: 0.0809 - dense_8_loss: 0.626 - ETA: 7:55 - loss: 0.8858 - dense_7_loss: 0.0809 - dense_8_loss: 0.626 - ETA: 7:55 - loss: 0.8856 - dense_7_loss: 0.0809 - dense_8_loss: 0.626 - ETA: 7:54 - loss: 0.8853 - dense_7_loss: 0.0808 - dense_8_loss: 0.625 - ETA: 7:54 - loss: 0.8851 - dense_7_loss: 0.0808 - dense_8_loss: 0.625 - ETA: 7:54 - loss: 0.8849 - dense_7_loss: 0.0808 - dense_8_loss: 0.625 - ETA: 7:54 - loss: 0.8847 - dense_7_loss: 0.0807 - dense_8_loss: 0.625 - ETA: 7:53 - loss: 0.8844 - dense_7_loss: 0.0807 - dense_8_loss: 0.625 - ETA: 7:53 - loss: 0.8842 - dense_7_loss: 0.0807 - dense_8_loss: 0.625 - ETA: 7:53 - loss: 0.8839 - dense_7_loss: 0.0806 - dense_8_loss: 0.625 - ETA: 7:52 - loss: 0.8838 - dense_7_loss: 0.0806 - dense_8_loss: 0.625 - ETA: 7:52 - loss: 0.8837 - dense_7_loss: 0.0806 - dense_8_los ...
#  349184/1209265 [=======>......................] - ETA: 7:36 - loss: 0.8720 - dense_7_loss: 0.0793 - dense_8_loss: 0.617 - ETA: 7:36 - loss: 0.8717 - dense_7_loss: 0.0792 - dense_8_loss: 0.617 - ETA: 7:35 - loss: 0.8716 - dense_7_loss: 0.0792 - dense_8_loss: 0.617 - ETA: 7:35 - loss: 0.8713 - dense_7_loss: 0.0792 - dense_8_loss: 0.617 - ETA: 7:35 - loss: 0.8711 - dense_7_loss: 0.0792 - dense_8_loss: 0.617 - ETA: 7:34 - loss: 0.8708 - dense_7_loss: 0.0791 - dense_8_loss: 0.616 - ETA: 7:34 - loss: 0.8707 - dense_7_loss: 0.0791 - dense_8_loss: 0.616 - ETA: 7:34 - loss: 0.8704 - dense_7_loss: 0.0791 - dense_8_loss: 0.616 - ETA: 7:34 - loss: 0.8702 - dense_7_loss: 0.0790 - dense_8_loss: 0.616 - ETA: 7:33 - loss: 0.8701 - dense_7_loss: 0.0790 - dense_8_loss: 0.616 - ETA: 7:33 - loss: 0.8699 - dense_7_loss: 0.0790 - dense_8_loss: 0.616 - ETA: 7:33 - loss: 0.8697 - dense_7_loss: 0.0790 - dense_8_loss: 0.616 - ETA: 7:33 - loss: 0.8697 - dense_7_loss: 0.0790 - dense_8_loss: 0.616 - ETA: 7:32 - loss: 0.8696 - dense_7_loss: 0.0790 - dense_8_loss: 0.615 - ETA: 7:32 - loss: 0.8695 - dense_7_loss: 0.0790 - dense_8_loss: 0.615 - ETA: 7:32 - loss: 0.8693 - dense_7_loss: 0.0790 - dense_8_loss: 0.615 - ETA: 7:31 - loss: 0.8691 - dense_7_loss: 0.0790 - dense_8_loss: 0.615 - ETA: 7:31 - loss: 0.8688 - dense_7_loss: 0.0789 - dense_8_loss: 0.615 - ETA: 7:31 - loss: 0.8686 - dense_7_loss: 0.0789 - dense_8_loss: 0.615 - ETA: 7:31 - loss: 0.8686 - dense_7_loss: 0.0790 - dense_8_loss: 0.615 - ETA: 7:30 - loss: 0.8685 - dense_7_loss: 0.0790 - dense_8_loss: 0.615 - ETA: 7:30 - loss: 0.8683 - dense_7_loss: 0.0789 - dense_8_loss: 0.615 - ETA: 7:30 - loss: 0.8681 - dense_7_loss: 0.0789 - dense_8_loss: 0.614 - ETA: 7:30 - loss: 0.8679 - dense_7_loss: 0.0789 - dense_8_loss: 0.614 - ETA: 7:29 - loss: 0.8677 - dense_7_loss: 0.0789 - dense_8_loss: 0.614 - ETA: 7:29 - loss: 0.8677 - dense_7_loss: 0.0789 - dense_8_loss: 0.614 - ETA: 7:29 - loss: 0.8674 - dense_7_loss: 0.0789 - dense_8_loss: 0.614 - ETA: 7:29 - loss: 0.8672 - dense_7_loss: 0.0788 - dense_8_loss: 0.614 - ETA: 7:28 - loss: 0.8670 - dense_7_loss: 0.0788 - dense_8_loss: 0.614 - ETA: 7:28 - loss: 0.8668 - dense_7_loss: 0.0788 - dense_8_loss: 0.614 - ETA: 7:28 - loss: 0.8667 - dense_7_loss: 0.0788 - dense_8_loss: 0.613 - ETA: 7:27 - loss: 0.8665 - dense_7_loss: 0.0788 - dense_8_loss: 0.613 - ETA: 7:27 - loss: 0.8663 - dense_7_loss: 0.0787 - dense_8_loss: 0.613 - ETA: 7:27 - loss: 0.8661 - dense_7_loss: 0.0787 - dense_8_loss: 0.613 - ETA: 7:27 - loss: 0.8659 - dense_7_loss: 0.0787 - dense_8_loss: 0.613 - ETA: 7:26 - loss: 0.8657 - dense_7_loss: 0.0787 - dense_8_loss: 0.613 - ETA: 7:26 - loss: 0.8656 - dense_7_loss: 0.0787 - dense_8_loss: 0.613 - ETA: 7:26 - loss: 0.8654 - dense_7_loss: 0.0786 - dense_8_loss: 0.613 - ETA: 7:26 - loss: 0.8652 - dense_7_loss: 0.0786 - dense_8_loss: 0.612 - ETA: 7:25 - loss: 0.8650 - dense_7_loss: 0.0786 - dense_8_loss: 0.612 - ETA: 7:25 - loss: 0.8648 - dense_7_loss: 0.0786 - dense_8_loss: 0.612 - ETA: 7:25 - loss: 0.8647 - dense_7_loss: 0.0786 - dense_8_loss: 0.612 - ETA: 7:24 - loss: 0.8645 - dense_7_loss: 0.0785 - dense_8_loss: 0.612 - ETA: 7:24 - loss: 0.8644 - dense_7_loss: 0.0785 - dense_8_loss: 0.612 - ETA: 7:24 - loss: 0.8641 - dense_7_loss: 0.0785 - dense_8_loss: 0.612 - ETA: 7:24 - loss: 0.8639 - dense_7_loss: 0.0785 - dense_8_loss: 0.612 - ETA: 7:23 - loss: 0.8638 - dense_7_loss: 0.0785 - dense_8_loss: 0.612 - ETA: 7:23 - loss: 0.8636 - dense_7_loss: 0.0784 - dense_8_loss: 0.611 - ETA: 7:23 - loss: 0.8634 - dense_7_loss: 0.0784 - dense_8_loss: 0.611 - ETA: 7:23 - loss: 0.8632 - dense_7_loss: 0.0784 - dense_8_loss: 0.611 - ETA: 7:22 - loss: 0.8631 - dense_7_loss: 0.0784 - dense_8_loss: 0.611 - ETA: 7:22 - loss: 0.8629 - dense_7_loss: 0.0784 - dense_8_loss: 0.611 - ETA: 7:22 - loss: 0.8627 - dense_7_loss: 0.0783 - dense_8_loss: 0.611 - ETA: 7:22 - loss: 0.8626 - dense_7_loss: 0.0784 - dense_8_loss: 0.611 - ETA: 7:21 - loss: 0.8624 - dense_7_loss: 0.0783 - dense_8_los ...
#  407552/1209265 [=========>....................] - ETA: 7:05 - loss: 0.8526 - dense_7_loss: 0.0775 - dense_8_loss: 0.603 - ETA: 7:05 - loss: 0.8525 - dense_7_loss: 0.0775 - dense_8_loss: 0.603 - ETA: 7:05 - loss: 0.8523 - dense_7_loss: 0.0775 - dense_8_loss: 0.603 - ETA: 7:04 - loss: 0.8522 - dense_7_loss: 0.0775 - dense_8_loss: 0.603 - ETA: 7:04 - loss: 0.8520 - dense_7_loss: 0.0775 - dense_8_loss: 0.603 - ETA: 7:04 - loss: 0.8518 - dense_7_loss: 0.0774 - dense_8_loss: 0.603 - ETA: 7:04 - loss: 0.8516 - dense_7_loss: 0.0774 - dense_8_loss: 0.603 - ETA: 7:03 - loss: 0.8514 - dense_7_loss: 0.0774 - dense_8_loss: 0.603 - ETA: 7:03 - loss: 0.8511 - dense_7_loss: 0.0773 - dense_8_loss: 0.602 - ETA: 7:03 - loss: 0.8509 - dense_7_loss: 0.0773 - dense_8_loss: 0.602 - ETA: 7:03 - loss: 0.8508 - dense_7_loss: 0.0773 - dense_8_loss: 0.602 - ETA: 7:02 - loss: 0.8506 - dense_7_loss: 0.0773 - dense_8_loss: 0.602 - ETA: 7:02 - loss: 0.8504 - dense_7_loss: 0.0773 - dense_8_loss: 0.602 - ETA: 7:02 - loss: 0.8502 - dense_7_loss: 0.0772 - dense_8_loss: 0.602 - ETA: 7:02 - loss: 0.8502 - dense_7_loss: 0.0773 - dense_8_loss: 0.602 - ETA: 7:01 - loss: 0.8500 - dense_7_loss: 0.0772 - dense_8_loss: 0.602 - ETA: 7:01 - loss: 0.8498 - dense_7_loss: 0.0772 - dense_8_loss: 0.602 - ETA: 7:01 - loss: 0.8496 - dense_7_loss: 0.0772 - dense_8_loss: 0.601 - ETA: 7:00 - loss: 0.8494 - dense_7_loss: 0.0772 - dense_8_loss: 0.601 - ETA: 7:00 - loss: 0.8492 - dense_7_loss: 0.0771 - dense_8_loss: 0.601 - ETA: 7:00 - loss: 0.8490 - dense_7_loss: 0.0771 - dense_8_loss: 0.601 - ETA: 7:00 - loss: 0.8489 - dense_7_loss: 0.0771 - dense_8_loss: 0.601 - ETA: 6:59 - loss: 0.8488 - dense_7_loss: 0.0771 - dense_8_loss: 0.601 - ETA: 6:59 - loss: 0.8486 - dense_7_loss: 0.0771 - dense_8_loss: 0.601 - ETA: 6:59 - loss: 0.8485 - dense_7_loss: 0.0771 - dense_8_loss: 0.601 - ETA: 6:59 - loss: 0.8482 - dense_7_loss: 0.0771 - dense_8_loss: 0.601 - ETA: 6:58 - loss: 0.8481 - dense_7_loss: 0.0771 - dense_8_loss: 0.600 - ETA: 6:58 - loss: 0.8480 - dense_7_loss: 0.0770 - dense_8_loss: 0.600 - ETA: 6:58 - loss: 0.8478 - dense_7_loss: 0.0770 - dense_8_loss: 0.600 - ETA: 6:58 - loss: 0.8476 - dense_7_loss: 0.0770 - dense_8_loss: 0.600 - ETA: 6:57 - loss: 0.8475 - dense_7_loss: 0.0770 - dense_8_loss: 0.600 - ETA: 6:57 - loss: 0.8473 - dense_7_loss: 0.0770 - dense_8_loss: 0.600 - ETA: 6:57 - loss: 0.8472 - dense_7_loss: 0.0770 - dense_8_loss: 0.600 - ETA: 6:57 - loss: 0.8469 - dense_7_loss: 0.0769 - dense_8_loss: 0.600 - ETA: 6:56 - loss: 0.8468 - dense_7_loss: 0.0769 - dense_8_loss: 0.599 - ETA: 6:56 - loss: 0.8467 - dense_7_loss: 0.0769 - dense_8_loss: 0.599 - ETA: 6:56 - loss: 0.8465 - dense_7_loss: 0.0769 - dense_8_loss: 0.599 - ETA: 6:55 - loss: 0.8463 - dense_7_loss: 0.0769 - dense_8_loss: 0.599 - ETA: 6:55 - loss: 0.8462 - dense_7_loss: 0.0769 - dense_8_loss: 0.599 - ETA: 6:55 - loss: 0.8460 - dense_7_loss: 0.0769 - dense_8_loss: 0.599 - ETA: 6:55 - loss: 0.8459 - dense_7_loss: 0.0769 - dense_8_loss: 0.599 - ETA: 6:54 - loss: 0.8457 - dense_7_loss: 0.0768 - dense_8_loss: 0.599 - ETA: 6:54 - loss: 0.8455 - dense_7_loss: 0.0768 - dense_8_loss: 0.599 - ETA: 6:54 - loss: 0.8453 - dense_7_loss: 0.0768 - dense_8_loss: 0.598 - ETA: 6:54 - loss: 0.8450 - dense_7_loss: 0.0767 - dense_8_loss: 0.598 - ETA: 6:53 - loss: 0.8448 - dense_7_loss: 0.0767 - dense_8_loss: 0.598 - ETA: 6:53 - loss: 0.8447 - dense_7_loss: 0.0767 - dense_8_loss: 0.598 - ETA: 6:53 - loss: 0.8445 - dense_7_loss: 0.0767 - dense_8_loss: 0.598 - ETA: 6:53 - loss: 0.8444 - dense_7_loss: 0.0767 - dense_8_loss: 0.598 - ETA: 6:52 - loss: 0.8442 - dense_7_loss: 0.0767 - dense_8_loss: 0.598 - ETA: 6:52 - loss: 0.8441 - dense_7_loss: 0.0767 - dense_8_loss: 0.598 - ETA: 6:52 - loss: 0.8439 - dense_7_loss: 0.0766 - dense_8_loss: 0.598 - ETA: 6:52 - loss: 0.8437 - dense_7_loss: 0.0766 - dense_8_loss: 0.597 - ETA: 6:51 - loss: 0.8436 - dense_7_loss: 0.0766 - dense_8_loss: 0.597 - ETA: 6:51 - loss: 0.8434 - dense_7_loss: 0.0766 - dense_8_los ...
#  465920/1209265 [==========>...................] - ETA: 6:35 - loss: 0.8339 - dense_7_loss: 0.0758 - dense_8_loss: 0.590 - ETA: 6:35 - loss: 0.8338 - dense_7_loss: 0.0758 - dense_8_loss: 0.590 - ETA: 6:35 - loss: 0.8337 - dense_7_loss: 0.0758 - dense_8_loss: 0.590 - ETA: 6:35 - loss: 0.8336 - dense_7_loss: 0.0758 - dense_8_loss: 0.590 - ETA: 6:34 - loss: 0.8335 - dense_7_loss: 0.0758 - dense_8_loss: 0.590 - ETA: 6:34 - loss: 0.8333 - dense_7_loss: 0.0758 - dense_8_loss: 0.590 - ETA: 6:34 - loss: 0.8331 - dense_7_loss: 0.0757 - dense_8_loss: 0.590 - ETA: 6:34 - loss: 0.8329 - dense_7_loss: 0.0757 - dense_8_loss: 0.590 - ETA: 6:33 - loss: 0.8328 - dense_7_loss: 0.0757 - dense_8_loss: 0.589 - ETA: 6:33 - loss: 0.8326 - dense_7_loss: 0.0757 - dense_8_loss: 0.589 - ETA: 6:33 - loss: 0.8324 - dense_7_loss: 0.0757 - dense_8_loss: 0.589 - ETA: 6:33 - loss: 0.8323 - dense_7_loss: 0.0757 - dense_8_loss: 0.589 - ETA: 6:32 - loss: 0.8322 - dense_7_loss: 0.0757 - dense_8_loss: 0.589 - ETA: 6:32 - loss: 0.8320 - dense_7_loss: 0.0756 - dense_8_loss: 0.589 - ETA: 6:32 - loss: 0.8319 - dense_7_loss: 0.0756 - dense_8_loss: 0.589 - ETA: 6:32 - loss: 0.8318 - dense_7_loss: 0.0756 - dense_8_loss: 0.589 - ETA: 6:31 - loss: 0.8318 - dense_7_loss: 0.0757 - dense_8_loss: 0.589 - ETA: 6:31 - loss: 0.8316 - dense_7_loss: 0.0757 - dense_8_loss: 0.588 - ETA: 6:31 - loss: 0.8315 - dense_7_loss: 0.0757 - dense_8_loss: 0.588 - ETA: 6:31 - loss: 0.8314 - dense_7_loss: 0.0756 - dense_8_loss: 0.588 - ETA: 6:30 - loss: 0.8311 - dense_7_loss: 0.0756 - dense_8_loss: 0.588 - ETA: 6:30 - loss: 0.8310 - dense_7_loss: 0.0756 - dense_8_loss: 0.588 - ETA: 6:30 - loss: 0.8308 - dense_7_loss: 0.0756 - dense_8_loss: 0.588 - ETA: 6:29 - loss: 0.8306 - dense_7_loss: 0.0755 - dense_8_loss: 0.588 - ETA: 6:29 - loss: 0.8305 - dense_7_loss: 0.0756 - dense_8_loss: 0.588 - ETA: 6:29 - loss: 0.8304 - dense_7_loss: 0.0755 - dense_8_loss: 0.588 - ETA: 6:29 - loss: 0.8302 - dense_7_loss: 0.0755 - dense_8_loss: 0.587 - ETA: 6:28 - loss: 0.8301 - dense_7_loss: 0.0755 - dense_8_loss: 0.587 - ETA: 6:28 - loss: 0.8300 - dense_7_loss: 0.0755 - dense_8_loss: 0.587 - ETA: 6:28 - loss: 0.8299 - dense_7_loss: 0.0755 - dense_8_loss: 0.587 - ETA: 6:28 - loss: 0.8297 - dense_7_loss: 0.0755 - dense_8_loss: 0.587 - ETA: 6:27 - loss: 0.8296 - dense_7_loss: 0.0755 - dense_8_loss: 0.587 - ETA: 6:27 - loss: 0.8295 - dense_7_loss: 0.0755 - dense_8_loss: 0.587 - ETA: 6:27 - loss: 0.8293 - dense_7_loss: 0.0755 - dense_8_loss: 0.587 - ETA: 6:27 - loss: 0.8291 - dense_7_loss: 0.0755 - dense_8_loss: 0.586 - ETA: 6:26 - loss: 0.8290 - dense_7_loss: 0.0755 - dense_8_loss: 0.586 - ETA: 6:26 - loss: 0.8289 - dense_7_loss: 0.0755 - dense_8_loss: 0.586 - ETA: 6:26 - loss: 0.8287 - dense_7_loss: 0.0754 - dense_8_loss: 0.586 - ETA: 6:26 - loss: 0.8285 - dense_7_loss: 0.0754 - dense_8_loss: 0.586 - ETA: 6:25 - loss: 0.8283 - dense_7_loss: 0.0754 - dense_8_loss: 0.586 - ETA: 6:25 - loss: 0.8282 - dense_7_loss: 0.0754 - dense_8_loss: 0.586 - ETA: 6:25 - loss: 0.8281 - dense_7_loss: 0.0754 - dense_8_loss: 0.586 - ETA: 6:25 - loss: 0.8279 - dense_7_loss: 0.0754 - dense_8_loss: 0.586 - ETA: 6:24 - loss: 0.8279 - dense_7_loss: 0.0754 - dense_8_loss: 0.585 - ETA: 6:24 - loss: 0.8277 - dense_7_loss: 0.0754 - dense_8_loss: 0.585 - ETA: 6:24 - loss: 0.8274 - dense_7_loss: 0.0753 - dense_8_loss: 0.585 - ETA: 6:24 - loss: 0.8273 - dense_7_loss: 0.0753 - dense_8_loss: 0.585 - ETA: 6:23 - loss: 0.8271 - dense_7_loss: 0.0753 - dense_8_loss: 0.585 - ETA: 6:23 - loss: 0.8270 - dense_7_loss: 0.0753 - dense_8_loss: 0.585 - ETA: 6:23 - loss: 0.8269 - dense_7_loss: 0.0753 - dense_8_loss: 0.585 - ETA: 6:23 - loss: 0.8267 - dense_7_loss: 0.0753 - dense_8_loss: 0.585 - ETA: 6:22 - loss: 0.8265 - dense_7_loss: 0.0752 - dense_8_loss: 0.585 - ETA: 6:22 - loss: 0.8264 - dense_7_loss: 0.0752 - dense_8_loss: 0.584 - ETA: 6:22 - loss: 0.8261 - dense_7_loss: 0.0752 - dense_8_loss: 0.584 - ETA: 6:22 - loss: 0.8259 - dense_7_loss: 0.0752 - dense_8_los ...
#  524288/1209265 [============>.................] - ETA: 6:06 - loss: 0.8170 - dense_7_loss: 0.0744 - dense_8_loss: 0.578 - ETA: 6:06 - loss: 0.8169 - dense_7_loss: 0.0744 - dense_8_loss: 0.578 - ETA: 6:05 - loss: 0.8168 - dense_7_loss: 0.0744 - dense_8_loss: 0.577 - ETA: 6:05 - loss: 0.8166 - dense_7_loss: 0.0744 - dense_8_loss: 0.577 - ETA: 6:05 - loss: 0.8165 - dense_7_loss: 0.0744 - dense_8_loss: 0.577 - ETA: 6:05 - loss: 0.8164 - dense_7_loss: 0.0744 - dense_8_loss: 0.577 - ETA: 6:04 - loss: 0.8162 - dense_7_loss: 0.0744 - dense_8_loss: 0.577 - ETA: 6:04 - loss: 0.8161 - dense_7_loss: 0.0744 - dense_8_loss: 0.577 - ETA: 6:04 - loss: 0.8159 - dense_7_loss: 0.0743 - dense_8_loss: 0.577 - ETA: 6:04 - loss: 0.8158 - dense_7_loss: 0.0744 - dense_8_loss: 0.577 - ETA: 6:03 - loss: 0.8157 - dense_7_loss: 0.0743 - dense_8_loss: 0.577 - ETA: 6:03 - loss: 0.8156 - dense_7_loss: 0.0744 - dense_8_loss: 0.577 - ETA: 6:03 - loss: 0.8155 - dense_7_loss: 0.0744 - dense_8_loss: 0.576 - ETA: 6:03 - loss: 0.8154 - dense_7_loss: 0.0744 - dense_8_loss: 0.576 - ETA: 6:02 - loss: 0.8153 - dense_7_loss: 0.0744 - dense_8_loss: 0.576 - ETA: 6:02 - loss: 0.8151 - dense_7_loss: 0.0743 - dense_8_loss: 0.576 - ETA: 6:02 - loss: 0.8150 - dense_7_loss: 0.0743 - dense_8_loss: 0.576 - ETA: 6:02 - loss: 0.8148 - dense_7_loss: 0.0743 - dense_8_loss: 0.576 - ETA: 6:01 - loss: 0.8147 - dense_7_loss: 0.0743 - dense_8_loss: 0.576 - ETA: 6:01 - loss: 0.8146 - dense_7_loss: 0.0743 - dense_8_loss: 0.576 - ETA: 6:01 - loss: 0.8144 - dense_7_loss: 0.0743 - dense_8_loss: 0.576 - ETA: 6:01 - loss: 0.8143 - dense_7_loss: 0.0743 - dense_8_loss: 0.575 - ETA: 6:00 - loss: 0.8141 - dense_7_loss: 0.0743 - dense_8_loss: 0.575 - ETA: 6:00 - loss: 0.8139 - dense_7_loss: 0.0742 - dense_8_loss: 0.575 - ETA: 6:00 - loss: 0.8138 - dense_7_loss: 0.0742 - dense_8_loss: 0.575 - ETA: 6:00 - loss: 0.8137 - dense_7_loss: 0.0742 - dense_8_loss: 0.575 - ETA: 5:59 - loss: 0.8135 - dense_7_loss: 0.0742 - dense_8_loss: 0.575 - ETA: 5:59 - loss: 0.8134 - dense_7_loss: 0.0742 - dense_8_loss: 0.575 - ETA: 5:59 - loss: 0.8132 - dense_7_loss: 0.0742 - dense_8_loss: 0.575 - ETA: 5:59 - loss: 0.8131 - dense_7_loss: 0.0742 - dense_8_loss: 0.575 - ETA: 5:58 - loss: 0.8129 - dense_7_loss: 0.0742 - dense_8_loss: 0.574 - ETA: 5:58 - loss: 0.8128 - dense_7_loss: 0.0741 - dense_8_loss: 0.574 - ETA: 5:58 - loss: 0.8126 - dense_7_loss: 0.0741 - dense_8_loss: 0.574 - ETA: 5:57 - loss: 0.8125 - dense_7_loss: 0.0741 - dense_8_loss: 0.574 - ETA: 5:57 - loss: 0.8123 - dense_7_loss: 0.0741 - dense_8_loss: 0.574 - ETA: 5:57 - loss: 0.8122 - dense_7_loss: 0.0741 - dense_8_loss: 0.574 - ETA: 5:57 - loss: 0.8120 - dense_7_loss: 0.0741 - dense_8_loss: 0.574 - ETA: 5:56 - loss: 0.8118 - dense_7_loss: 0.0740 - dense_8_loss: 0.574 - ETA: 5:56 - loss: 0.8116 - dense_7_loss: 0.0740 - dense_8_loss: 0.574 - ETA: 5:56 - loss: 0.8115 - dense_7_loss: 0.0740 - dense_8_loss: 0.574 - ETA: 5:56 - loss: 0.8114 - dense_7_loss: 0.0740 - dense_8_loss: 0.573 - ETA: 5:55 - loss: 0.8113 - dense_7_loss: 0.0740 - dense_8_loss: 0.573 - ETA: 5:55 - loss: 0.8111 - dense_7_loss: 0.0740 - dense_8_loss: 0.573 - ETA: 5:55 - loss: 0.8109 - dense_7_loss: 0.0740 - dense_8_loss: 0.573 - ETA: 5:55 - loss: 0.8107 - dense_7_loss: 0.0739 - dense_8_loss: 0.573 - ETA: 5:54 - loss: 0.8106 - dense_7_loss: 0.0739 - dense_8_loss: 0.573 - ETA: 5:54 - loss: 0.8105 - dense_7_loss: 0.0739 - dense_8_loss: 0.573 - ETA: 5:54 - loss: 0.8103 - dense_7_loss: 0.0739 - dense_8_loss: 0.573 - ETA: 5:54 - loss: 0.8102 - dense_7_loss: 0.0739 - dense_8_loss: 0.573 - ETA: 5:53 - loss: 0.8101 - dense_7_loss: 0.0739 - dense_8_loss: 0.572 - ETA: 5:53 - loss: 0.8099 - dense_7_loss: 0.0739 - dense_8_loss: 0.572 - ETA: 5:53 - loss: 0.8098 - dense_7_loss: 0.0739 - dense_8_loss: 0.572 - ETA: 5:53 - loss: 0.8096 - dense_7_loss: 0.0739 - dense_8_loss: 0.572 - ETA: 5:52 - loss: 0.8094 - dense_7_loss: 0.0738 - dense_8_loss: 0.572 - ETA: 5:52 - loss: 0.8093 - dense_7_loss: 0.0738 - dense_8_los ...
#  582656/1209265 [=============>................] - ETA: 5:37 - loss: 0.8012 - dense_7_loss: 0.0733 - dense_8_loss: 0.566 - ETA: 5:36 - loss: 0.8011 - dense_7_loss: 0.0733 - dense_8_loss: 0.566 - ETA: 5:36 - loss: 0.8009 - dense_7_loss: 0.0732 - dense_8_loss: 0.565 - ETA: 5:36 - loss: 0.8007 - dense_7_loss: 0.0732 - dense_8_loss: 0.565 - ETA: 5:36 - loss: 0.8006 - dense_7_loss: 0.0732 - dense_8_loss: 0.565 - ETA: 5:35 - loss: 0.8005 - dense_7_loss: 0.0732 - dense_8_loss: 0.565 - ETA: 5:35 - loss: 0.8004 - dense_7_loss: 0.0732 - dense_8_loss: 0.565 - ETA: 5:35 - loss: 0.8003 - dense_7_loss: 0.0732 - dense_8_loss: 0.565 - ETA: 5:35 - loss: 0.8001 - dense_7_loss: 0.0732 - dense_8_loss: 0.565 - ETA: 5:34 - loss: 0.8001 - dense_7_loss: 0.0732 - dense_8_loss: 0.565 - ETA: 5:34 - loss: 0.7999 - dense_7_loss: 0.0732 - dense_8_loss: 0.565 - ETA: 5:34 - loss: 0.7998 - dense_7_loss: 0.0732 - dense_8_loss: 0.564 - ETA: 5:34 - loss: 0.7997 - dense_7_loss: 0.0732 - dense_8_loss: 0.564 - ETA: 5:33 - loss: 0.7995 - dense_7_loss: 0.0732 - dense_8_loss: 0.564 - ETA: 5:33 - loss: 0.7994 - dense_7_loss: 0.0732 - dense_8_loss: 0.564 - ETA: 5:33 - loss: 0.7993 - dense_7_loss: 0.0732 - dense_8_loss: 0.564 - ETA: 5:33 - loss: 0.7992 - dense_7_loss: 0.0732 - dense_8_loss: 0.564 - ETA: 5:32 - loss: 0.7990 - dense_7_loss: 0.0731 - dense_8_loss: 0.564 - ETA: 5:32 - loss: 0.7989 - dense_7_loss: 0.0731 - dense_8_loss: 0.564 - ETA: 5:32 - loss: 0.7989 - dense_7_loss: 0.0732 - dense_8_loss: 0.564 - ETA: 5:32 - loss: 0.7987 - dense_7_loss: 0.0731 - dense_8_loss: 0.564 - ETA: 5:31 - loss: 0.7986 - dense_7_loss: 0.0731 - dense_8_loss: 0.563 - ETA: 5:31 - loss: 0.7985 - dense_7_loss: 0.0731 - dense_8_loss: 0.563 - ETA: 5:31 - loss: 0.7984 - dense_7_loss: 0.0731 - dense_8_loss: 0.563 - ETA: 5:31 - loss: 0.7983 - dense_7_loss: 0.0731 - dense_8_loss: 0.563 - ETA: 5:30 - loss: 0.7982 - dense_7_loss: 0.0731 - dense_8_loss: 0.563 - ETA: 5:30 - loss: 0.7980 - dense_7_loss: 0.0731 - dense_8_loss: 0.563 - ETA: 5:30 - loss: 0.7979 - dense_7_loss: 0.0731 - dense_8_loss: 0.563 - ETA: 5:29 - loss: 0.7977 - dense_7_loss: 0.0731 - dense_8_loss: 0.563 - ETA: 5:29 - loss: 0.7976 - dense_7_loss: 0.0731 - dense_8_loss: 0.563 - ETA: 5:29 - loss: 0.7975 - dense_7_loss: 0.0731 - dense_8_loss: 0.563 - ETA: 5:29 - loss: 0.7974 - dense_7_loss: 0.0731 - dense_8_loss: 0.562 - ETA: 5:28 - loss: 0.7973 - dense_7_loss: 0.0731 - dense_8_loss: 0.562 - ETA: 5:28 - loss: 0.7971 - dense_7_loss: 0.0730 - dense_8_loss: 0.562 - ETA: 5:28 - loss: 0.7969 - dense_7_loss: 0.0730 - dense_8_loss: 0.562 - ETA: 5:28 - loss: 0.7968 - dense_7_loss: 0.0730 - dense_8_loss: 0.562 - ETA: 5:27 - loss: 0.7966 - dense_7_loss: 0.0730 - dense_8_loss: 0.562 - ETA: 5:27 - loss: 0.7965 - dense_7_loss: 0.0730 - dense_8_loss: 0.562 - ETA: 5:27 - loss: 0.7964 - dense_7_loss: 0.0730 - dense_8_loss: 0.562 - ETA: 5:27 - loss: 0.7963 - dense_7_loss: 0.0730 - dense_8_loss: 0.562 - ETA: 5:26 - loss: 0.7962 - dense_7_loss: 0.0730 - dense_8_loss: 0.561 - ETA: 5:26 - loss: 0.7961 - dense_7_loss: 0.0730 - dense_8_loss: 0.561 - ETA: 5:26 - loss: 0.7960 - dense_7_loss: 0.0730 - dense_8_loss: 0.561 - ETA: 5:26 - loss: 0.7959 - dense_7_loss: 0.0730 - dense_8_loss: 0.561 - ETA: 5:25 - loss: 0.7958 - dense_7_loss: 0.0730 - dense_8_loss: 0.561 - ETA: 5:25 - loss: 0.7956 - dense_7_loss: 0.0730 - dense_8_loss: 0.561 - ETA: 5:25 - loss: 0.7955 - dense_7_loss: 0.0730 - dense_8_loss: 0.561 - ETA: 5:25 - loss: 0.7953 - dense_7_loss: 0.0729 - dense_8_loss: 0.561 - ETA: 5:24 - loss: 0.7952 - dense_7_loss: 0.0729 - dense_8_loss: 0.561 - ETA: 5:24 - loss: 0.7951 - dense_7_loss: 0.0729 - dense_8_loss: 0.561 - ETA: 5:24 - loss: 0.7949 - dense_7_loss: 0.0729 - dense_8_loss: 0.560 - ETA: 5:24 - loss: 0.7948 - dense_7_loss: 0.0729 - dense_8_loss: 0.560 - ETA: 5:23 - loss: 0.7946 - dense_7_loss: 0.0729 - dense_8_loss: 0.560 - ETA: 5:23 - loss: 0.7945 - dense_7_loss: 0.0729 - dense_8_loss: 0.560 - ETA: 5:23 - loss: 0.7944 - dense_7_loss: 0.0729 - dense_8_los ...
#  641024/1209265 [==============>...............] - ETA: 5:08 - loss: 0.7873 - dense_7_loss: 0.0726 - dense_8_loss: 0.554 - ETA: 5:07 - loss: 0.7873 - dense_7_loss: 0.0726 - dense_8_loss: 0.554 - ETA: 5:07 - loss: 0.7872 - dense_7_loss: 0.0726 - dense_8_loss: 0.554 - ETA: 5:07 - loss: 0.7871 - dense_7_loss: 0.0726 - dense_8_loss: 0.554 - ETA: 5:06 - loss: 0.7870 - dense_7_loss: 0.0726 - dense_8_loss: 0.554 - ETA: 5:06 - loss: 0.7868 - dense_7_loss: 0.0726 - dense_8_loss: 0.553 - ETA: 5:06 - loss: 0.7867 - dense_7_loss: 0.0726 - dense_8_loss: 0.553 - ETA: 5:06 - loss: 0.7866 - dense_7_loss: 0.0726 - dense_8_loss: 0.553 - ETA: 5:05 - loss: 0.7864 - dense_7_loss: 0.0725 - dense_8_loss: 0.553 - ETA: 5:05 - loss: 0.7863 - dense_7_loss: 0.0725 - dense_8_loss: 0.553 - ETA: 5:05 - loss: 0.7862 - dense_7_loss: 0.0725 - dense_8_loss: 0.553 - ETA: 5:05 - loss: 0.7860 - dense_7_loss: 0.0725 - dense_8_loss: 0.553 - ETA: 5:04 - loss: 0.7859 - dense_7_loss: 0.0725 - dense_8_loss: 0.553 - ETA: 5:04 - loss: 0.7858 - dense_7_loss: 0.0725 - dense_8_loss: 0.553 - ETA: 5:04 - loss: 0.7857 - dense_7_loss: 0.0725 - dense_8_loss: 0.553 - ETA: 5:04 - loss: 0.7855 - dense_7_loss: 0.0725 - dense_8_loss: 0.552 - ETA: 5:03 - loss: 0.7855 - dense_7_loss: 0.0725 - dense_8_loss: 0.552 - ETA: 5:03 - loss: 0.7853 - dense_7_loss: 0.0725 - dense_8_loss: 0.552 - ETA: 5:03 - loss: 0.7852 - dense_7_loss: 0.0725 - dense_8_loss: 0.552 - ETA: 5:03 - loss: 0.7851 - dense_7_loss: 0.0725 - dense_8_loss: 0.552 - ETA: 5:02 - loss: 0.7850 - dense_7_loss: 0.0725 - dense_8_loss: 0.552 - ETA: 5:02 - loss: 0.7849 - dense_7_loss: 0.0725 - dense_8_loss: 0.552 - ETA: 5:02 - loss: 0.7847 - dense_7_loss: 0.0725 - dense_8_loss: 0.552 - ETA: 5:02 - loss: 0.7846 - dense_7_loss: 0.0725 - dense_8_loss: 0.552 - ETA: 5:01 - loss: 0.7845 - dense_7_loss: 0.0724 - dense_8_loss: 0.552 - ETA: 5:01 - loss: 0.7844 - dense_7_loss: 0.0725 - dense_8_loss: 0.551 - ETA: 5:01 - loss: 0.7843 - dense_7_loss: 0.0724 - dense_8_loss: 0.551 - ETA: 5:01 - loss: 0.7842 - dense_7_loss: 0.0724 - dense_8_loss: 0.551 - ETA: 5:00 - loss: 0.7841 - dense_7_loss: 0.0724 - dense_8_loss: 0.551 - ETA: 5:00 - loss: 0.7840 - dense_7_loss: 0.0724 - dense_8_loss: 0.551 - ETA: 5:00 - loss: 0.7838 - dense_7_loss: 0.0724 - dense_8_loss: 0.551 - ETA: 5:00 - loss: 0.7837 - dense_7_loss: 0.0724 - dense_8_loss: 0.551 - ETA: 4:59 - loss: 0.7837 - dense_7_loss: 0.0724 - dense_8_loss: 0.551 - ETA: 4:59 - loss: 0.7836 - dense_7_loss: 0.0724 - dense_8_loss: 0.551 - ETA: 4:59 - loss: 0.7835 - dense_7_loss: 0.0724 - dense_8_loss: 0.551 - ETA: 4:59 - loss: 0.7834 - dense_7_loss: 0.0724 - dense_8_loss: 0.550 - ETA: 4:58 - loss: 0.7833 - dense_7_loss: 0.0724 - dense_8_loss: 0.550 - ETA: 4:58 - loss: 0.7832 - dense_7_loss: 0.0724 - dense_8_loss: 0.550 - ETA: 4:58 - loss: 0.7830 - dense_7_loss: 0.0724 - dense_8_loss: 0.550 - ETA: 4:58 - loss: 0.7829 - dense_7_loss: 0.0724 - dense_8_loss: 0.550 - ETA: 4:57 - loss: 0.7828 - dense_7_loss: 0.0724 - dense_8_loss: 0.550 - ETA: 4:57 - loss: 0.7827 - dense_7_loss: 0.0724 - dense_8_loss: 0.550 - ETA: 4:57 - loss: 0.7826 - dense_7_loss: 0.0724 - dense_8_loss: 0.550 - ETA: 4:57 - loss: 0.7824 - dense_7_loss: 0.0724 - dense_8_loss: 0.550 - ETA: 4:56 - loss: 0.7823 - dense_7_loss: 0.0724 - dense_8_loss: 0.550 - ETA: 4:56 - loss: 0.7822 - dense_7_loss: 0.0724 - dense_8_loss: 0.549 - ETA: 4:56 - loss: 0.7821 - dense_7_loss: 0.0724 - dense_8_loss: 0.549 - ETA: 4:56 - loss: 0.7820 - dense_7_loss: 0.0724 - dense_8_loss: 0.549 - ETA: 4:55 - loss: 0.7818 - dense_7_loss: 0.0723 - dense_8_loss: 0.549 - ETA: 4:55 - loss: 0.7817 - dense_7_loss: 0.0723 - dense_8_loss: 0.549 - ETA: 4:55 - loss: 0.7815 - dense_7_loss: 0.0723 - dense_8_loss: 0.549 - ETA: 4:54 - loss: 0.7814 - dense_7_loss: 0.0723 - dense_8_loss: 0.549 - ETA: 4:54 - loss: 0.7812 - dense_7_loss: 0.0723 - dense_8_loss: 0.549 - ETA: 4:54 - loss: 0.7812 - dense_7_loss: 0.0723 - dense_8_loss: 0.549 - ETA: 4:54 - loss: 0.7811 - dense_7_loss: 0.0723 - dense_8_los ...
# ...
# 1108992/1209265 [==========================>...] - ETA: 1:34 - loss: 0.2939 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:33 - loss: 0.2939 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:33 - loss: 0.2939 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:33 - loss: 0.2939 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:32 - loss: 0.2939 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:32 - loss: 0.2939 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:32 - loss: 0.2939 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:32 - loss: 0.2938 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:31 - loss: 0.2938 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:31 - loss: 0.2938 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:31 - loss: 0.2938 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:30 - loss: 0.2938 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:30 - loss: 0.2938 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:30 - loss: 0.2938 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:29 - loss: 0.2937 - dense_7_loss: 0.0539 - dense_8_loss: 0.120 - ETA: 1:29 - loss: 0.2937 - dense_7_loss: 0.0539 - dense_8_loss: 0.120 - ETA: 1:29 - loss: 0.2937 - dense_7_loss: 0.0539 - dense_8_loss: 0.120 - ETA: 1:29 - loss: 0.2937 - dense_7_loss: 0.0539 - dense_8_loss: 0.120 - ETA: 1:28 - loss: 0.2937 - dense_7_loss: 0.0539 - dense_8_loss: 0.120 - ETA: 1:28 - loss: 0.2936 - dense_7_loss: 0.0539 - dense_8_loss: 0.120 - ETA: 1:28 - loss: 0.2936 - dense_7_loss: 0.0539 - dense_8_loss: 0.120 - ETA: 1:27 - loss: 0.2937 - dense_7_loss: 0.0539 - dense_8_loss: 0.120 - ETA: 1:27 - loss: 0.2937 - dense_7_loss: 0.0539 - dense_8_loss: 0.120 - ETA: 1:27 - loss: 0.2937 - dense_7_loss: 0.0539 - dense_8_loss: 0.120 - ETA: 1:26 - loss: 0.2937 - dense_7_loss: 0.0539 - dense_8_loss: 0.120 - ETA: 1:26 - loss: 0.2937 - dense_7_loss: 0.0539 - dense_8_loss: 0.120 - ETA: 1:26 - loss: 0.2937 - dense_7_loss: 0.0539 - dense_8_loss: 0.120 - ETA: 1:25 - loss: 0.2937 - dense_7_loss: 0.0539 - dense_8_loss: 0.120 - ETA: 1:25 - loss: 0.2937 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:25 - loss: 0.2937 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:25 - loss: 0.2937 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:24 - loss: 0.2937 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:24 - loss: 0.2937 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:24 - loss: 0.2937 - dense_7_loss: 0.0539 - dense_8_loss: 0.120 - ETA: 1:23 - loss: 0.2937 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:23 - loss: 0.2937 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:23 - loss: 0.2937 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:22 - loss: 0.2937 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:22 - loss: 0.2937 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:22 - loss: 0.2937 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:22 - loss: 0.2938 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:21 - loss: 0.2937 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:21 - loss: 0.2938 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:21 - loss: 0.2938 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:20 - loss: 0.2938 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:20 - loss: 0.2938 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:20 - loss: 0.2938 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:19 - loss: 0.2938 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:19 - loss: 0.2938 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:19 - loss: 0.2938 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:18 - loss: 0.2939 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:18 - loss: 0.2938 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:18 - loss: 0.2939 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:18 - loss: 0.2938 - dense_7_loss: 0.0540 - dense_8_loss: 0.120 - ETA: 1:17 - loss: 0.2938 - dense_7_loss: 0.0540 - dense_8_los ...
# 1168896/1209265 [===========================>..] - ETA: 59s - loss: 0.2938 - dense_7_loss: 0.0541 - dense_8_loss: 0.12 - ETA: 59s - loss: 0.2938 - dense_7_loss: 0.0541 - dense_8_loss: 0.12 - ETA: 58s - loss: 0.2938 - dense_7_loss: 0.0541 - dense_8_loss: 0.12 - ETA: 58s - loss: 0.2938 - dense_7_loss: 0.0541 - dense_8_loss: 0.12 - ETA: 58s - loss: 0.2938 - dense_7_loss: 0.0541 - dense_8_loss: 0.12 - ETA: 57s - loss: 0.2938 - dense_7_loss: 0.0541 - dense_8_loss: 0.12 - ETA: 57s - loss: 0.2939 - dense_7_loss: 0.0541 - dense_8_loss: 0.12 - ETA: 57s - loss: 0.2939 - dense_7_loss: 0.0541 - dense_8_loss: 0.12 - ETA: 57s - loss: 0.2939 - dense_7_loss: 0.0541 - dense_8_loss: 0.12 - ETA: 56s - loss: 0.2939 - dense_7_loss: 0.0541 - dense_8_loss: 0.12 - ETA: 56s - loss: 0.2938 - dense_7_loss: 0.0541 - dense_8_loss: 0.12 - ETA: 56s - loss: 0.2939 - dense_7_loss: 0.0541 - dense_8_loss: 0.12 - ETA: 55s - loss: 0.2939 - dense_7_loss: 0.0541 - dense_8_loss: 0.12 - ETA: 55s - loss: 0.2939 - dense_7_loss: 0.0541 - dense_8_loss: 0.12 - ETA: 55s - loss: 0.2938 - dense_7_loss: 0.0541 - dense_8_loss: 0.12 - ETA: 54s - loss: 0.2938 - dense_7_loss: 0.0541 - dense_8_loss: 0.12 - ETA: 54s - loss: 0.2938 - dense_7_loss: 0.0541 - dense_8_loss: 0.12 - ETA: 54s - loss: 0.2938 - dense_7_loss: 0.0541 - dense_8_loss: 0.12 - ETA: 53s - loss: 0.2938 - dense_7_loss: 0.0541 - dense_8_loss: 0.12 - ETA: 53s - loss: 0.2938 - dense_7_loss: 0.0541 - dense_8_loss: 0.12 - ETA: 53s - loss: 0.2938 - dense_7_loss: 0.0541 - dense_8_loss: 0.12 - ETA: 53s - loss: 0.2937 - dense_7_loss: 0.0541 - dense_8_loss: 0.12 - ETA: 52s - loss: 0.2937 - dense_7_loss: 0.0541 - dense_8_loss: 0.12 - ETA: 52s - loss: 0.2937 - dense_7_loss: 0.0541 - dense_8_loss: 0.12 - ETA: 52s - loss: 0.2937 - dense_7_loss: 0.0541 - dense_8_loss: 0.12 - ETA: 51s - loss: 0.2937 - dense_7_loss: 0.0541 - dense_8_loss: 0.12 - ETA: 51s - loss: 0.2937 - dense_7_loss: 0.0541 - dense_8_loss: 0.12 - ETA: 51s - loss: 0.2937 - dense_7_loss: 0.0540 - dense_8_loss: 0.12 - ETA: 50s - loss: 0.2937 - dense_7_loss: 0.0540 - dense_8_loss: 0.12 - ETA: 50s - loss: 0.2937 - dense_7_loss: 0.0540 - dense_8_loss: 0.12 - ETA: 50s - loss: 0.2936 - dense_7_loss: 0.0540 - dense_8_loss: 0.12 - ETA: 50s - loss: 0.2936 - dense_7_loss: 0.0540 - dense_8_loss: 0.12 - ETA: 49s - loss: 0.2936 - dense_7_loss: 0.0540 - dense_8_loss: 0.12 - ETA: 49s - loss: 0.2936 - dense_7_loss: 0.0540 - dense_8_loss: 0.12 - ETA: 49s - loss: 0.2936 - dense_7_loss: 0.0540 - dense_8_loss: 0.12 - ETA: 48s - loss: 0.2936 - dense_7_loss: 0.0540 - dense_8_loss: 0.12 - ETA: 48s - loss: 0.2936 - dense_7_loss: 0.0540 - dense_8_loss: 0.12 - ETA: 48s - loss: 0.2936 - dense_7_loss: 0.0540 - dense_8_loss: 0.12 - ETA: 47s - loss: 0.2936 - dense_7_loss: 0.0540 - dense_8_loss: 0.12 - ETA: 47s - loss: 0.2936 - dense_7_loss: 0.0540 - dense_8_loss: 0.12 - ETA: 47s - loss: 0.2936 - dense_7_loss: 0.0540 - dense_8_loss: 0.12 - ETA: 46s - loss: 0.2936 - dense_7_loss: 0.0540 - dense_8_loss: 0.12 - ETA: 46s - loss: 0.2936 - dense_7_loss: 0.0540 - dense_8_loss: 0.12 - ETA: 46s - loss: 0.2936 - dense_7_loss: 0.0540 - dense_8_loss: 0.12 - ETA: 46s - loss: 0.2935 - dense_7_loss: 0.0540 - dense_8_loss: 0.12 - ETA: 45s - loss: 0.2935 - dense_7_loss: 0.0540 - dense_8_loss: 0.12 - ETA: 45s - loss: 0.2935 - dense_7_loss: 0.0540 - dense_8_loss: 0.12 - ETA: 45s - loss: 0.2935 - dense_7_loss: 0.0540 - dense_8_loss: 0.12 - ETA: 44s - loss: 0.2935 - dense_7_loss: 0.0540 - dense_8_loss: 0.12 - ETA: 44s - loss: 0.2935 - dense_7_loss: 0.0540 - dense_8_loss: 0.12 - ETA: 44s - loss: 0.2935 - dense_7_loss: 0.0540 - dense_8_loss: 0.12 - ETA: 43s - loss: 0.2935 - dense_7_loss: 0.0540 - dense_8_loss: 0.12 - ETA: 43s - loss: 0.2935 - dense_7_loss: 0.0540 - dense_8_loss: 0.12 - ETA: 43s - loss: 0.2935 - dense_7_loss: 0.0540 - dense_8_loss: 0.12 - ETA: 42s - loss: 0.2935 - dense_7_loss: 0.0540 - dense_8_loss: 0.12 - ETA: 42s - loss: 0.2935 - dense_7_loss: 0.0540 - dense_8_loss: 0.12 - ETA: 42s - loss: 0.2935 - den ...
# 1209265/1209265 [==============================] - ETA: 23s - loss: 0.2930 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 23s - loss: 0.2930 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 23s - loss: 0.2930 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 22s - loss: 0.2930 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 22s - loss: 0.2930 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 22s - loss: 0.2930 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 21s - loss: 0.2930 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 21s - loss: 0.2930 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 21s - loss: 0.2930 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 21s - loss: 0.2930 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 20s - loss: 0.2930 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 20s - loss: 0.2930 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 20s - loss: 0.2929 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 19s - loss: 0.2929 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 19s - loss: 0.2930 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 19s - loss: 0.2930 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 18s - loss: 0.2929 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 18s - loss: 0.2929 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 18s - loss: 0.2929 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 17s - loss: 0.2929 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 17s - loss: 0.2929 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 17s - loss: 0.2929 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 17s - loss: 0.2929 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 16s - loss: 0.2929 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 16s - loss: 0.2929 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 16s - loss: 0.2929 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 15s - loss: 0.2929 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 15s - loss: 0.2929 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 15s - loss: 0.2929 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 14s - loss: 0.2929 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 14s - loss: 0.2929 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 14s - loss: 0.2929 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 13s - loss: 0.2929 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 13s - loss: 0.2929 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 13s - loss: 0.2929 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 13s - loss: 0.2929 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 12s - loss: 0.2929 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 12s - loss: 0.2929 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 12s - loss: 0.2929 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 11s - loss: 0.2929 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 11s - loss: 0.2929 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 11s - loss: 0.2929 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 10s - loss: 0.2929 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 10s - loss: 0.2929 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 10s - loss: 0.2929 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 10s - loss: 0.2929 - dense_7_loss: 0.0539 - dense_8_loss: 0.11 - ETA: 9s - loss: 0.2929 - dense_7_loss: 0.0539 - dense_8_loss: 0.1198 - ETA: 9s - loss: 0.2929 - dense_7_loss: 0.0539 - dense_8_loss: 0.119 - ETA: 9s - loss: 0.2929 - dense_7_loss: 0.0539 - dense_8_loss: 0.119 - ETA: 8s - loss: 0.2929 - dense_7_loss: 0.0539 - dense_8_loss: 0.119 - ETA: 8s - loss: 0.2928 - dense_7_loss: 0.0539 - dense_8_loss: 0.119 - ETA: 8s - loss: 0.2928 - dense_7_loss: 0.0539 - dense_8_loss: 0.119 - ETA: 7s - loss: 0.2928 - dense_7_loss: 0.0539 - dense_8_loss: 0.119 - ETA: 7s - loss: 0.2928 - dense_7_loss: 0.0539 - dense_8_loss: 0.119 - ETA: 7s - loss: 0.2928 - dense_7_loss: 0.0539 - dense_8_loss: 0.119 - ETA: 6s - loss: 0.2928 - dense_7_loss: 0.0539 - dense_8_loss: 0.119 - ETA: 6s - loss: 0.2928 - den ...

# %%
# Saving the model
model.save('../input/mymodel/my_model_new.h5')

# %% [markdown]
# ## Prediction for Validation data

# %%
#Prediction for Validation data
val_preds.append(model.predict(cv_data, batch_size=512)[0].flatten())

# %%
y_data[val_ind].shape
# Out:
# (595609, 2)

# %%
cv_preds= np.array(val_preds).T
print(cv_preds.shape)
score=roc_auc_score(y_data[val_ind][:,0],cv_preds)*100
print("Validation auc is: ",score)
# Out:
# (595609, 1)
# Validation auc is:  96.2946537314013

# %% [markdown]
# ## Prediction on test data

# %%
#Prediction for test data
checkpoint_predictions.append(model.predict(test_data, batch_size=512)[0].flatten())

# %%
test_preds= np.array(checkpoint_predictions).T
test_preds.shape
# Out:
# (97320, 1)

# %%
submission = pd.read_csv('../Data/sample_submission.csv', index_col='id')
submission['prediction'] = test_preds
submission.to_csv('submission_new.csv')
submission.head()
# Out:
#          prediction
# id
# 7097320    0.002563
# 7097321    0.010771
# 7097322    0.215665
# 7097323    0.001489
# 7097324    0.000401
